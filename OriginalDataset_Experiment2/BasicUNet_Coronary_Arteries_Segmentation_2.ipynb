# %%
import os
from glob import glob

import os
import json
import shutil
import tempfile
import time

import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib

from monai.losses import DiceLoss, DiceFocalLoss, DiceCELoss # type: ignore
from monai.inferers import sliding_window_inference # type: ignore
from monai import transforms # type: ignore
from monai.transforms import Compose, LoadImaged, ToTensord, EnsureChannelFirstd, Spacingd, CropForegroundd, Resized, Activations, AsDiscrete, ScaleIntensityRanged, SpatialCropd # type: ignore


from monai.config import print_config # type: ignore
from monai.metrics import DiceMetric # type: ignore
from monai.utils.enums import MetricReduction # type: ignore
from monai.networks.nets import UNet, BasicUNet # type: ignore
from monai import data
from monai.data import Dataset, DataLoader, decollate_batch
from functools import partial

import torch

#print_config()
# Out:
# c:\Users\Lenovo\anaconda3\envs\deeplearning\Lib\site-packages\ignite\handlers\checkpoint.py:16: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import ZeroRedundancyOptimizer

# %%
# Setup directory where checkpoints are stored

# Run from Lab's pc 
# checkpoint_dir = "C:\\Users\\manto\\OneDrive\\Desktop\\Coronary-Arteries-Segmentation-with-BasicUNet\\LimitedData"
# Run from my laptop 
checkpoint_dir = "D:\\Coronary-Arteries-Segmentation-with-BasicUNet\\OriginalDataset_Experiment2"


# Average Meter is used to track the average of a metric over multiple iterations
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0            # Stores the latest value
        self.avg = 0            # Stores the running average
        self.sum = 0            # Sum of all values
        self.count = 0          # Number of updates

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n     # Accumulate sum
        self.count += n         # Increase count
        self.avg = np.where(self.count > 0, self.sum / self.count, self.sum)

# Function that saves a PyTorch model checkpoint (model's state, epoch number this was achieved, best accuracy so far)
def save_checkpoint(model, epoch, filename="best_model.pth", best_acc=0, dir_add=checkpoint_dir):
    state_dict = model.state_dict()
    save_dict = {"epoch": epoch, "best_acc": best_acc, "state_dict": state_dict}
    filename = os.path.join(dir_add, filename)
    torch.save(save_dict, filename)
    print("Saving checkpoint", filename)

# %%
# Experiment 2

# Run from Lab's PC & my laptop
data_dir = "D:\\Electra\\data"

train_images = sorted(glob(os.path.join(data_dir, 'Cropped_TrainingData', '*.img.nii.gz')))
train_labels = sorted(glob(os.path.join(data_dir, 'Cropped_TrainingData', '*.label.nii.gz')))

val_images = sorted(glob(os.path.join(data_dir, 'Cropped_ValidationData', '*.img.nii.gz')))
val_labels = sorted(glob(os.path.join(data_dir, 'Cropped_ValidationData', '*.label.nii.gz')))

#train_images = train_images[:320]
#train_labels = train_labels[:320]

#val_images = val_images[:80]
#val_labels = val_labels[:80]

# Create dictionaries with a path of each image and each label
train_files = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]
val_files = [{"image": image_name, "label": label_name} for image_name, label_name in zip(val_images, val_labels)]

roi = (128, 128, 128)
# Due to inefficiency of GPU I reduced batch size to 1 from 2, and sw_batch_size to 2 from 4.
batch_size = 1
sw_batch_size = 2
infer_overlap = 0.5
max_epochs = 100
val_every = 5

train_transform = transforms.Compose(
    [
        transforms.LoadImageD(keys=["image", "label"]),
        transforms.EnsureChannelFirstd(keys=["image", "label"]),
        transforms.ScaleIntensityRanged(
            keys=["image"],
            a_min=-1024,
            a_max=1500,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        #Spacingd(
        #    keys=["image", "label"],
        #    pixdim=(0.38, 0.38, 0.5),  
        #    mode=("bilinear", "nearest")
        #),
        #transforms.Orientationd(keys=["image", "label"], axcodes="RAS"),
        transforms.Resized(keys=["image", "label"], spatial_size=(roi[0], roi[1], roi[2]), mode=['area', 'nearest']),
        transforms.ToTensorD(keys=["image", "label"]),
    ]
)          

val_transform = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image", "label"]),
        transforms.EnsureChannelFirstd(keys=["image", "label"]),
        transforms.ScaleIntensityRanged(
            keys=["image"],
            a_min=-1024,
            a_max=1500,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        #Spacingd(
        #    keys=["image", "label"],
        #    pixdim=(0.38, 0.38, 0.5),  
        #    mode=("bilinear", "nearest")
        #),
        #transforms.Orientationd(keys=["image", "label"], axcodes="RAS"),
        transforms.Resized(keys=["image", "label"], spatial_size=(roi[0], roi[1], roi[2]), mode=['area', 'nearest']),
        transforms.ToTensorD(keys=["image", "label"]),
    ]
)

train_ds = data.Dataset(data=train_files, transform=train_transform)

train_loader = data.DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8,
    pin_memory=True,
)
    
val_ds = data.Dataset(data=val_files, transform=val_transform)
    
val_loader = data.DataLoader(
    val_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=8,
    pin_memory=True,
)

# %%
import torch
import matplotlib.pyplot as plt

# Get a single batch from the train_loader (faster than first())
batch = next(iter(train_loader))  # Only takes the first batch instead of the whole dataset

# Extract the first sample from the batch
image = batch["image"][0, 0, :, :, 64]  # Middle slice in the z-direction
label = batch["label"][0, 0, :, :, 64]

# Plot the image and its corresponding label
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Slice of Transformed Image")
plt.imshow(image.numpy(), cmap="gray")

plt.subplot(1, 2, 2)
plt.title("Label")
plt.imshow(label.numpy())

plt.show()

# %%
from monai.transforms import SaveImaged
import os
import nibabel as nib

# Output directory
output_dir = "D:\\Electra\\data\\transformed_images"
# Make sure it exists
os.makedirs(output_dir, exist_ok=True)

def save_transformed_sample(index=0):
    sample = train_ds[index]

    # Extract original image path and name
    image_meta_path = sample["image"].meta["filename_or_obj"]
    image_name = os.path.basename(image_meta_path)
    print(f"Original image filename: {image_name}")

    # Show original affine from the source NIfTI
    original_nib = nib.load(image_meta_path)
    print("Original affine (from source NIfTI):")
    print(original_nib.affine)

    # Show MONAI metadata affines
    print("Transformed image .meta['affine']:", sample["image"].meta.get("affine", "Not available"))
    print("Transformed image .affine (if exists):", getattr(sample["image"], "affine", "No .affine"))

    #  Save 
    saver = SaveImaged(
        keys=["image", "label"],
        output_dir=output_dir,
        output_postfix="transformed",
        separate_folder=False,
        resample=False,                  # Keep original spacing/orientation
        print_log=True
    )

    saver({"image": sample["image"], "label": sample["label"]})

# Change index to run 
save_transformed_sample(4)
# Out:
# Original image filename: cropped_101.img.nii.gz
# Original affine (from source NIfTI):
# [[-3.18359375e-01 -0.00000000e+00  0.00000000e+00 -1.39648438e-01]
#  [-0.00000000e+00  3.18359375e-01 -0.00000000e+00  1.13405273e+02]
#  [ 0.00000000e+00  0.00000000e+00  5.00000000e-01  1.72449997e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Transformed image .meta['affine']: tensor([[ -0.7213,   0.0000,   0.0000,  -0.3411],
#         [  0.0000,   0.7760,   0.0000, 113.6341],
#         [  0.0000,   0.0000,   0.6719, 172.5359],
#         [  0.0000,   0.0000,   0.0000,   1.0000]], dtype=torch.float64)
# Transformed image .affine (if exists): tensor([[ -0.7213,   0.0000,   0.0000,  -0.3411],
#         [  0.0000,   0.7760,   0.0000, 113.6341],
#         [  0.0000,   0.0000,   0.6719, 172.5359],
#         [  0.0000,   0.0000,   0.0000,   1.0000]], dtype=torch.float64)
# 2025-04-28 17:35:19,178 INFO image_writer.py:197 - writing: D:\Electra\data\transformed_images\cropped_101.img_transformed.nii.gz
# 2025-04-28 17:35:19,762 INFO image_writer.py:197 - writing: D:\Electra\data\transformed_images\cropped_101.label_transformed.nii.gz

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.is_available())
torch.cuda.empty_cache()

# Initialize the BasicUNet model
model = BasicUNet(
    spatial_dims=3,                                               # For 3D segmentation
    in_channels=1,                                                # Grayscale input images
    out_channels=2,                                               # 2 output classes: background and coronary arteries
    features=(32, 32, 64, 128, 256, 32),                          # Feature sizes
    act=('LeakyReLU', {'inplace': True, 'negative_slope': 0.1}),  # Activation function
    norm=('instance', {'affine': True}),                          # Normalization
    dropout=0.1,                                                  # Optional dropout for regularization
    upsample='deconv'                                             # Use deconvolution for upsampling
).to(device)
# Out:
# True
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %%
torch.backends.cudnn.benchmark = True

dice_loss = DiceCELoss(include_background=True, to_onehot_y=True, sigmoid=True)
dice_acc  = DiceMetric(include_background=True, reduction="mean", get_not_nans=True)

post_sigmoid = Activations(sigmoid=True)
post_pred    = AsDiscrete(argmax=False, threshold=0.5)

model_inferer = partial(
    sliding_window_inference,
    roi_size=[roi[0], roi[1], roi[2]],
    sw_batch_size=sw_batch_size,
    predictor=model,
    overlap=infer_overlap,
)

optimizer = torch.optim.AdamW(model.parameters(), lr=0.0002, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

# %%
def train_epoch(model, loader, optimizer, epoch, loss_func, device, max_epochs, batch_size):
    model.train()  # Set model to training mode
    run_loss = AverageMeter()
    start_time = time.time()

    for idx, batch_data in enumerate(loader):
        # Move data to the appropriate device
        data, target = batch_data["image"].to(device), batch_data["label"].to(device)
        
        # Reset gradients
        optimizer.zero_grad()
        
        # Forward pass
        logits = model(data)
        
        # Compute loss
        loss = loss_func(logits, target)
        
        # Backward pass
        loss.backward()
        
        # Clip gradients because its useful for stability in large models
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        # Optimizer step
        optimizer.step()
        optimizer.zero_grad()  # Clear the gradients after each step

        
        # Update loss tracking
        run_loss.update(loss.item(), n=data.size(0))  # Use actual batch size
        
        # Log information periodically
        if idx % (len(loader) // 10 or 1) == 0:  # Log every 10% of an epoch
            elapsed = time.time() - start_time
            print(
                f"Epoch {epoch}/{max_epochs} Batch {idx}/{len(loader)} "
                f"Loss: {run_loss.avg:.4f} Time: {elapsed:.2f}s"
            )
            start_time = time.time()  # Reset start time for next log

    return run_loss.avg

def val_epoch(
    model,
    loader,
    epoch,
    acc_func,
    device,
    model_inferer=None,
    post_sigmoid=None,
    post_pred=None,
):
    model.eval()  # Set model to evaluation mode
    run_acc = AverageMeter()
    start_time = time.time()

    with torch.no_grad():
        for idx, batch_data in enumerate(loader):
            # Move data to the appropriate device
            data, target = batch_data["image"].to(device), batch_data["label"].to(device)
            
            # Model inference
            logits = model_inferer(data) if model_inferer else model(data)
            
            # Post-processing
            val_labels_list = decollate_batch(target)
            val_outputs_list = decollate_batch(logits)
            val_output_convert = [post_pred(post_sigmoid(val_pred_tensor)) for val_pred_tensor in val_outputs_list]
            
            # Compute metrics
            acc_func.reset()  # Reset metric accumulator
            acc_func(y_pred=val_output_convert, y=val_labels_list)
            acc, not_nans = acc_func.aggregate()
            run_acc.update(acc.cpu().numpy(), n=not_nans.cpu().numpy())
            
            # Log batch metrics periodically
            if idx % (len(loader) // 10 or 1) == 0:  # Log every 10% of the epoch
                dice_tc = run_acc.avg[0]  # First metric (e.g., binary Dice score)
                elapsed = time.time() - start_time
                print(
                    f"Validation {epoch}/{max_epochs} Batch {idx}/{len(loader)} "
                    f"Dice_TC: {dice_tc:.4f} Time: {elapsed:.2f}s"
                )
                start_time = time.time()  # Reset timer

    return run_acc.avg

# %%
def trainer(
    model,
    train_loader,
    val_loader,
    optimizer,
    loss_func,
    acc_func,
    scheduler=None,
    model_inferer=None,
    start_epoch=0,
    post_sigmoid=None,
    post_pred=None,
    max_epochs=max_epochs,                  # Maximum number of epochs
    val_every=val_every,                    # Frequency for validation
    device="cuda",                          # Specify the device
    save_path="best_model.pth",             # Path to save the best model
):
    val_acc_max = 0.0                       # Track the best validation accuracy (Dice score)
    dices_avg = []                          # Store average Dice scores across epochs
    loss_epochs = []                        # Store training loss per epoch
    trains_epoch = []                       # Store epoch numbers

    for epoch in range(start_epoch, max_epochs):
        print(time.ctime(), f"Epoch {epoch}/{max_epochs - 1}")
        epoch_start_time = time.time()

        # Training step
        train_loss = train_epoch(
            model=model,
            loader=train_loader,
            optimizer=optimizer,
            epoch=epoch,
            loss_func=loss_func,
            device=device,  # Pass the device
            max_epochs=max_epochs,  # Pass max_epochs for logging
            batch_size=train_loader.batch_size,  # Retrieve batch size from loader
        )

        print(
            f"Training {epoch}/{max_epochs - 1} - Loss: {train_loss:.4f} - "
            f"Time: {time.time() - epoch_start_time:.2f}s"
        )

        loss_epochs.append(train_loss)  # Store training loss for the epoch
        trains_epoch.append(epoch)  # Store the epoch number

        # Validate every 'val_every' epochs or at the first epoch
        if (epoch + 1) % val_every == 0 or epoch == 0:
            val_start_time = time.time()

            # Validation step
            val_acc = val_epoch(
                model=model,
                loader=val_loader,
                epoch=epoch,
                acc_func=acc_func,
                model_inferer=model_inferer,
                post_sigmoid=post_sigmoid,
                post_pred=post_pred,
                device=device,  # Pass the device
            )

            # Compute the average Dice score
            val_avg_acc = np.mean(val_acc)
            dices_avg.append(val_avg_acc)  # Store validation accuracy for the epoch

            print(
                f"Validation {epoch}/{max_epochs - 1} - Avg Dice: {val_avg_acc:.4f} - "
                f"Time: {time.time() - val_start_time:.2f}s"
            )

            # Check for the best validation accuracy
            if val_avg_acc > val_acc_max:
                print(f"New Best Accuracy: {val_acc_max:.4f} --> {val_avg_acc:.4f}")
                val_acc_max = val_avg_acc  # Update best validation accuracy

                # Save the best model checkpoint
                torch.save(model.state_dict(), save_path)
                print(f"Saved Best Model to {save_path}")

        # Update the learning rate scheduler
        if scheduler:
            scheduler.step()

    # Training finished, print final stats
    print(f"Training Complete! Best Validation Dice Score: {val_acc_max:.4f}")

    return val_acc_max, dices_avg, loss_epochs, trains_epoch

# %%
start_epoch = 0  

# Run the trainer function
val_acc_max, dices_avg, loss_epochs, trains_epoch = trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    loss_func=dice_loss,                                    # Dice loss for binary segmentation
    acc_func=dice_acc,                                      # Dice accuracy for performance evaluation
    scheduler=scheduler,                                    # Learning rate scheduler
    model_inferer=model_inferer,                            # Handles inference steps (e.g., softmax/sigmoid)
    start_epoch=start_epoch,                                # Starting epoch (useful for resuming training)
    post_sigmoid=post_sigmoid,                              # Apply sigmoid for probability conversion
    post_pred=post_pred,                                    # Thresholding function to get binary predictions
    max_epochs=max_epochs,                                  # Total number of epochs for training
    val_every=val_every,                                    # Perform validation every 10 epochs
    device="cuda" if torch.cuda.is_available() else "cpu",  # Device selection
    save_path="best_model.pth",                             # Path to save the best model
)
# Out:
# Tue Apr  8 11:38:09 2025 Epoch 0/99
# Epoch 0/100 Batch 0/641 Loss: 1.4253 Time: 65.84s
# Epoch 0/100 Batch 64/641 Loss: 1.0536 Time: 34.10s
# Epoch 0/100 Batch 128/641 Loss: 0.9519 Time: 33.47s
# Epoch 0/100 Batch 192/641 Loss: 0.8940 Time: 33.52s
# Epoch 0/100 Batch 256/641 Loss: 0.8527 Time: 33.64s
# Epoch 0/100 Batch 320/641 Loss: 0.8201 Time: 33.61s
# Epoch 0/100 Batch 384/641 Loss: 0.7931 Time: 33.65s
# Epoch 0/100 Batch 448/641 Loss: 0.7700 Time: 33.65s
# Epoch 0/100 Batch 512/641 Loss: 0.7499 Time: 33.64s
# Epoch 0/100 Batch 576/641 Loss: 0.7323 Time: 33.65s
# Epoch 0/100 Batch 640/641 Loss: 0.7166 Time: 33.66s
# Training 0/99 - Loss: 0.7166 - Time: 403.79s
# Validation 0/100 Batch 0/160 Dice_TC: 0.7439 Time: 9.92s
# Validation 0/100 Batch 16/160 Dice_TC: 0.7657 Time: 3.92s
# Validation 0/100 Batch 32/160 Dice_TC: 0.7662 Time: 3.53s
# Validation 0/100 Batch 48/160 Dice_TC: 0.7685 Time: 3.31s
# Validation 0/100 Batch 64/160 Dice_TC: 0.7659 Time: 3.14s
# Validation 0/100 Batch 80/160 Dice_TC: 0.7698 Time: 3.00s
# Validation 0/100 Batch 96/160 Dice_TC: 0.7696 Time: 2.95s
# Validation 0/100 Batch 112/160 Dice_TC: 0.7697 Time: 3.92s
# Validation 0/100 Batch 128/160 Dice_TC: 0.7693 Time: 3.80s
# Validation 0/100 Batch 144/160 Dice_TC: 0.7689 Time: 2.76s
# Validation 0/99 - Avg Dice: 0.7684 - Time: 43.65s
# New Best Accuracy: 0.0000 --> 0.7684
# Saved Best Model to best_model.pth
# Tue Apr  8 11:45:37 2025 Epoch 1/99
# Epoch 1/100 Batch 0/641 Loss: 0.5633 Time: 50.18s
# Epoch 1/100 Batch 64/641 Loss: 0.5615 Time: 34.02s
# Epoch 1/100 Batch 128/641 Loss: 0.5562 Time: 33.50s
# Epoch 1/100 Batch 192/641 Loss: 0.5505 Time: 33.72s
# Epoch 1/100 Batch 256/641 Loss: 0.5453 Time: 33.19s
# Epoch 1/100 Batch 320/641 Loss: 0.5406 Time: 32.80s
# Epoch 1/100 Batch 384/641 Loss: 0.5363 Time: 32.76s
# Epoch 1/100 Batch 448/641 Loss: 0.5320 Time: 32.77s
# Epoch 1/100 Batch 512/641 Loss: 0.5278 Time: 32.77s
# Epoch 1/100 Batch 576/641 Loss: 0.5236 Time: 32.78s
# Epoch 1/100 Batch 640/641 Loss: 0.5195 Time: 32.77s
# Training 1/99 - Loss: 0.5195 - Time: 382.57s
# Tue Apr  8 11:51:59 2025 Epoch 2/99
# Epoch 2/100 Batch 0/641 Loss: 0.4822 Time: 48.17s
# Epoch 2/100 Batch 64/641 Loss: 0.4727 Time: 32.66s
# Epoch 2/100 Batch 128/641 Loss: 0.4663 Time: 32.79s
# Epoch 2/100 Batch 192/641 Loss: 0.4597 Time: 32.78s
# Epoch 2/100 Batch 256/641 Loss: 0.4530 Time: 32.82s
# Epoch 2/100 Batch 320/641 Loss: 0.4457 Time: 32.80s
# Epoch 2/100 Batch 384/641 Loss: 0.4363 Time: 32.81s
# Epoch 2/100 Batch 448/641 Loss: 0.4254 Time: 32.81s
# Epoch 2/100 Batch 512/641 Loss: 0.4136 Time: 32.82s
# Epoch 2/100 Batch 576/641 Loss: 0.4007 Time: 32.83s
# Epoch 2/100 Batch 640/641 Loss: 0.3884 Time: 32.81s
# Training 2/99 - Loss: 0.3884 - Time: 377.42s
# Tue Apr  8 11:58:17 2025 Epoch 3/99
# Epoch 3/100 Batch 0/641 Loss: 0.2379 Time: 48.46s
# Epoch 3/100 Batch 64/641 Loss: 0.2524 Time: 33.25s
# Epoch 3/100 Batch 128/641 Loss: 0.2408 Time: 32.73s
# Epoch 3/100 Batch 192/641 Loss: 0.2318 Time: 32.95s
# Epoch 3/100 Batch 256/641 Loss: 0.2242 Time: 32.81s
# Epoch 3/100 Batch 320/641 Loss: 0.2170 Time: 32.81s
# Epoch 3/100 Batch 384/641 Loss: 0.2111 Time: 32.83s
# Epoch 3/100 Batch 448/641 Loss: 0.2058 Time: 32.82s
# Epoch 3/100 Batch 512/641 Loss: 0.2009 Time: 32.82s
# Epoch 3/100 Batch 576/641 Loss: 0.1967 Time: 32.81s
# Epoch 3/100 Batch 640/641 Loss: 0.1926 Time: 32.80s
# Training 3/99 - Loss: 0.1926 - Time: 378.43s
# Tue Apr  8 12:04:35 2025 Epoch 4/99
# Epoch 4/100 Batch 0/641 Loss: 0.1469 Time: 48.52s
# Epoch 4/100 Batch 64/641 Loss: 0.1586 Time: 33.18s
# Epoch 4/100 Batch 128/641 Loss: 0.1534 Time: 32.76s
# Epoch 4/100 Batch 192/641 Loss: 0.1516 Time: 32.84s
# Epoch 4/100 Batch 256/641 Loss: 0.1505 Time: 32.86s
# Epoch 4/100 Batch 320/641 Loss: 0.1500 Time: 32.85s
# Epoch 4/100 Batch 384/641 Loss: 0.1478 Time: 32.85s
# Epoch 4/100 Batch 448/641 Loss: 0.1471 Time: 32.87s
# Epoch 4/100 Batch 512/641 Loss: 0.1462 Time: 32.85s
# Epoch 4/100 Batch 576/641 Loss: 0.1458 Time: 32.87s
# Epoch 4/100 Batch 640/641 Loss: 0.1459 Time: 32.84s
# Training 4/99 - Loss: 0.1459 - Time: 378.64s
# Validation 4/100 Batch 0/160 Dice_TC: 0.8935 Time: 9.60s
# Validation 4/100 Batch 16/160 Dice_TC: 0.8892 Time: 3.61s
# Validation 4/100 Batch 32/160 Dice_TC: 0.8904 Time: 3.75s
# Validation 4/100 Batch 48/160 Dice_TC: 0.8919 Time: 3.02s
# Validation 4/100 Batch 64/160 Dice_TC: 0.8895 Time: 2.90s
# Validation 4/100 Batch 80/160 Dice_TC: 0.8913 Time: 3.47s
# Validation 4/100 Batch 96/160 Dice_TC: 0.8904 Time: 2.91s
# Validation 4/100 Batch 112/160 Dice_TC: 0.8908 Time: 3.43s
# Validation 4/100 Batch 128/160 Dice_TC: 0.8917 Time: 3.48s
# Validation 4/100 Batch 144/160 Dice_TC: 0.8903 Time: 2.97s
# Validation 4/99 - Avg Dice: 0.8907 - Time: 42.55s
# New Best Accuracy: 0.7684 --> 0.8907
# Saved Best Model to best_model.pth
# Tue Apr  8 12:11:36 2025 Epoch 5/99
# Epoch 5/100 Batch 0/641 Loss: 0.1229 Time: 49.35s
# Epoch 5/100 Batch 64/641 Loss: 0.1338 Time: 33.10s
# Epoch 5/100 Batch 128/641 Loss: 0.1352 Time: 32.67s
# Epoch 5/100 Batch 192/641 Loss: 0.1343 Time: 32.68s
# Epoch 5/100 Batch 256/641 Loss: 0.1322 Time: 32.82s
# Epoch 5/100 Batch 320/641 Loss: 0.1328 Time: 32.82s
# Epoch 5/100 Batch 384/641 Loss: 0.1331 Time: 32.83s
# Epoch 5/100 Batch 448/641 Loss: 0.1335 Time: 32.85s
# Epoch 5/100 Batch 512/641 Loss: 0.1332 Time: 32.83s
# Epoch 5/100 Batch 576/641 Loss: 0.1334 Time: 32.82s
# Epoch 5/100 Batch 640/641 Loss: 0.1322 Time: 32.85s
# Training 5/99 - Loss: 0.1322 - Time: 378.92s
# Tue Apr  8 12:17:55 2025 Epoch 6/99
# Epoch 6/100 Batch 0/641 Loss: 0.1332 Time: 48.69s
# Epoch 6/100 Batch 64/641 Loss: 0.1264 Time: 33.17s
# Epoch 6/100 Batch 128/641 Loss: 0.1246 Time: 32.66s
# Epoch 6/100 Batch 192/641 Loss: 0.1264 Time: 32.72s
# Epoch 6/100 Batch 256/641 Loss: 0.1274 Time: 32.79s
# Epoch 6/100 Batch 320/641 Loss: 0.1262 Time: 32.86s
# Epoch 6/100 Batch 384/641 Loss: 0.1257 Time: 32.84s
# Epoch 6/100 Batch 448/641 Loss: 0.1255 Time: 32.86s
# Epoch 6/100 Batch 512/641 Loss: 0.1256 Time: 32.83s
# Epoch 6/100 Batch 576/641 Loss: 0.1254 Time: 32.84s
# Epoch 6/100 Batch 640/641 Loss: 0.1258 Time: 32.84s
# Training 6/99 - Loss: 0.1258 - Time: 378.40s
# Tue Apr  8 12:24:14 2025 Epoch 7/99
# Epoch 7/100 Batch 0/641 Loss: 0.1138 Time: 48.41s
# Epoch 7/100 Batch 64/641 Loss: 0.1254 Time: 33.15s
# Epoch 7/100 Batch 128/641 Loss: 0.1249 Time: 32.84s
# Epoch 7/100 Batch 192/641 Loss: 0.1245 Time: 32.66s
# Epoch 7/100 Batch 256/641 Loss: 0.1233 Time: 32.80s
# Epoch 7/100 Batch 320/641 Loss: 0.1228 Time: 33.13s
# Epoch 7/100 Batch 384/641 Loss: 0.1224 Time: 32.79s
# Epoch 7/100 Batch 448/641 Loss: 0.1226 Time: 32.82s
# Epoch 7/100 Batch 512/641 Loss: 0.1225 Time: 32.80s
# Epoch 7/100 Batch 576/641 Loss: 0.1219 Time: 32.82s
# Epoch 7/100 Batch 640/641 Loss: 0.1211 Time: 32.80s
# Training 7/99 - Loss: 0.1211 - Time: 378.34s
# Tue Apr  8 12:30:32 2025 Epoch 8/99
# Epoch 8/100 Batch 0/641 Loss: 0.1288 Time: 48.54s
# Epoch 8/100 Batch 64/641 Loss: 0.1258 Time: 33.16s
# Epoch 8/100 Batch 128/641 Loss: 0.1204 Time: 32.63s
# Epoch 8/100 Batch 192/641 Loss: 0.1208 Time: 32.84s
# Epoch 8/100 Batch 256/641 Loss: 0.1204 Time: 32.77s
# Epoch 8/100 Batch 320/641 Loss: 0.1193 Time: 33.05s
# Epoch 8/100 Batch 384/641 Loss: 0.1197 Time: 32.83s
# Epoch 8/100 Batch 448/641 Loss: 0.1192 Time: 32.84s
# Epoch 8/100 Batch 512/641 Loss: 0.1191 Time: 32.83s
# Epoch 8/100 Batch 576/641 Loss: 0.1191 Time: 32.83s
# Epoch 8/100 Batch 640/641 Loss: 0.1186 Time: 32.83s
# Training 8/99 - Loss: 0.1186 - Time: 378.46s
# Tue Apr  8 12:36:51 2025 Epoch 9/99
# Epoch 9/100 Batch 0/641 Loss: 0.1021 Time: 48.56s
# Epoch 9/100 Batch 64/641 Loss: 0.1151 Time: 33.22s
# Epoch 9/100 Batch 128/641 Loss: 0.1193 Time: 32.70s
# Epoch 9/100 Batch 192/641 Loss: 0.1170 Time: 32.80s
# Epoch 9/100 Batch 256/641 Loss: 0.1170 Time: 32.82s
# Epoch 9/100 Batch 320/641 Loss: 0.1152 Time: 32.84s
# Epoch 9/100 Batch 384/641 Loss: 0.1157 Time: 32.83s
# Epoch 9/100 Batch 448/641 Loss: 0.1153 Time: 32.83s
# Epoch 9/100 Batch 512/641 Loss: 0.1161 Time: 32.84s
# Epoch 9/100 Batch 576/641 Loss: 0.1167 Time: 32.82s
# Epoch 9/100 Batch 640/641 Loss: 0.1165 Time: 33.08s
# Training 9/99 - Loss: 0.1165 - Time: 378.68s
# Validation 9/100 Batch 0/160 Dice_TC: 0.8935 Time: 9.22s
# Validation 9/100 Batch 16/160 Dice_TC: 0.8985 Time: 4.21s
# Validation 9/100 Batch 32/160 Dice_TC: 0.9000 Time: 3.24s
# Validation 9/100 Batch 48/160 Dice_TC: 0.9006 Time: 2.95s
# Validation 9/100 Batch 64/160 Dice_TC: 0.8989 Time: 3.62s
# Validation 9/100 Batch 80/160 Dice_TC: 0.9008 Time: 3.02s
# Validation 9/100 Batch 96/160 Dice_TC: 0.9000 Time: 3.11s
# Validation 9/100 Batch 112/160 Dice_TC: 0.9004 Time: 2.97s
# Validation 9/100 Batch 128/160 Dice_TC: 0.9012 Time: 3.80s
# Validation 9/100 Batch 144/160 Dice_TC: 0.9001 Time: 3.02s
# Validation 9/99 - Avg Dice: 0.8999 - Time: 42.67s
# New Best Accuracy: 0.8907 --> 0.8999
# Saved Best Model to best_model.pth
# Tue Apr  8 12:43:52 2025 Epoch 10/99
# Epoch 10/100 Batch 0/641 Loss: 0.0774 Time: 49.02s
# Epoch 10/100 Batch 64/641 Loss: 0.1132 Time: 33.14s
# Epoch 10/100 Batch 128/641 Loss: 0.1189 Time: 32.67s
# Epoch 10/100 Batch 192/641 Loss: 0.1175 Time: 32.70s
# Epoch 10/100 Batch 256/641 Loss: 0.1171 Time: 32.73s
# Epoch 10/100 Batch 320/641 Loss: 0.1161 Time: 32.96s
# Epoch 10/100 Batch 384/641 Loss: 0.1158 Time: 32.79s
# Epoch 10/100 Batch 448/641 Loss: 0.1159 Time: 32.80s
# Epoch 10/100 Batch 512/641 Loss: 0.1151 Time: 33.02s
# Epoch 10/100 Batch 576/641 Loss: 0.1151 Time: 33.28s
# Epoch 10/100 Batch 640/641 Loss: 0.1143 Time: 33.11s
# Training 10/99 - Loss: 0.1143 - Time: 379.60s
# Tue Apr  8 12:50:12 2025 Epoch 11/99
# Epoch 11/100 Batch 0/641 Loss: 0.1473 Time: 48.28s
# Epoch 11/100 Batch 64/641 Loss: 0.1153 Time: 32.62s
# Epoch 11/100 Batch 128/641 Loss: 0.1129 Time: 32.72s
# Epoch 11/100 Batch 192/641 Loss: 0.1118 Time: 32.73s
# Epoch 11/100 Batch 256/641 Loss: 0.1109 Time: 32.75s
# Epoch 11/100 Batch 320/641 Loss: 0.1107 Time: 32.83s
# Epoch 11/100 Batch 384/641 Loss: 0.1108 Time: 32.87s
# Epoch 11/100 Batch 448/641 Loss: 0.1108 Time: 32.92s
# Epoch 11/100 Batch 512/641 Loss: 0.1112 Time: 32.85s
# Epoch 11/100 Batch 576/641 Loss: 0.1116 Time: 32.88s
# Epoch 11/100 Batch 640/641 Loss: 0.1124 Time: 32.85s
# Training 11/99 - Loss: 0.1124 - Time: 377.61s
# Tue Apr  8 12:56:29 2025 Epoch 12/99
# Epoch 12/100 Batch 0/641 Loss: 0.1305 Time: 51.34s
# Epoch 12/100 Batch 64/641 Loss: 0.1100 Time: 32.71s
# Epoch 12/100 Batch 128/641 Loss: 0.1106 Time: 32.74s
# Epoch 12/100 Batch 192/641 Loss: 0.1114 Time: 32.91s
# Epoch 12/100 Batch 256/641 Loss: 0.1129 Time: 33.30s
# Epoch 12/100 Batch 320/641 Loss: 0.1132 Time: 33.30s
# Epoch 12/100 Batch 384/641 Loss: 0.1130 Time: 33.11s
# Epoch 12/100 Batch 448/641 Loss: 0.1120 Time: 33.04s
# Epoch 12/100 Batch 512/641 Loss: 0.1115 Time: 32.99s
# Epoch 12/100 Batch 576/641 Loss: 0.1111 Time: 33.00s
# Epoch 12/100 Batch 640/641 Loss: 0.1110 Time: 32.99s
# Training 12/99 - Loss: 0.1110 - Time: 382.79s
# Tue Apr  8 13:02:52 2025 Epoch 13/99
# Epoch 13/100 Batch 0/641 Loss: 0.1082 Time: 49.25s
# Epoch 13/100 Batch 64/641 Loss: 0.1081 Time: 32.86s
# Epoch 13/100 Batch 128/641 Loss: 0.1086 Time: 32.93s
# Epoch 13/100 Batch 192/641 Loss: 0.1088 Time: 33.05s
# Epoch 13/100 Batch 256/641 Loss: 0.1083 Time: 32.81s
# Epoch 13/100 Batch 320/641 Loss: 0.1100 Time: 32.81s
# Epoch 13/100 Batch 384/641 Loss: 0.1101 Time: 32.87s
# Epoch 13/100 Batch 448/641 Loss: 0.1099 Time: 33.07s
# Epoch 13/100 Batch 512/641 Loss: 0.1101 Time: 32.89s
# Epoch 13/100 Batch 576/641 Loss: 0.1098 Time: 32.80s
# Epoch 13/100 Batch 640/641 Loss: 0.1096 Time: 32.79s
# Training 13/99 - Loss: 0.1096 - Time: 379.47s
# Tue Apr  8 13:09:11 2025 Epoch 14/99
# Epoch 14/100 Batch 0/641 Loss: 0.1217 Time: 47.85s
# Epoch 14/100 Batch 64/641 Loss: 0.1041 Time: 32.64s
# Epoch 14/100 Batch 128/641 Loss: 0.1061 Time: 32.72s
# Epoch 14/100 Batch 192/641 Loss: 0.1082 Time: 32.80s
# Epoch 14/100 Batch 256/641 Loss: 0.1087 Time: 32.96s
# Epoch 14/100 Batch 320/641 Loss: 0.1093 Time: 33.23s
# Epoch 14/100 Batch 384/641 Loss: 0.1096 Time: 32.97s
# Epoch 14/100 Batch 448/641 Loss: 0.1092 Time: 32.96s
# Epoch 14/100 Batch 512/641 Loss: 0.1087 Time: 32.83s
# Epoch 14/100 Batch 576/641 Loss: 0.1086 Time: 32.82s
# Epoch 14/100 Batch 640/641 Loss: 0.1087 Time: 32.85s
# Training 14/99 - Loss: 0.1087 - Time: 377.98s
# Validation 14/100 Batch 0/160 Dice_TC: 0.8998 Time: 9.15s
# Validation 14/100 Batch 16/160 Dice_TC: 0.8981 Time: 3.89s
# Validation 14/100 Batch 32/160 Dice_TC: 0.8991 Time: 3.52s
# Validation 14/100 Batch 48/160 Dice_TC: 0.8997 Time: 3.48s
# Validation 14/100 Batch 64/160 Dice_TC: 0.8980 Time: 2.53s
# Validation 14/100 Batch 80/160 Dice_TC: 0.9004 Time: 3.30s
# Validation 14/100 Batch 96/160 Dice_TC: 0.9003 Time: 2.98s
# Validation 14/100 Batch 112/160 Dice_TC: 0.9006 Time: 3.72s
# Validation 14/100 Batch 128/160 Dice_TC: 0.9012 Time: 3.89s
# Validation 14/100 Batch 144/160 Dice_TC: 0.9001 Time: 2.44s
# Validation 14/99 - Avg Dice: 0.8997 - Time: 42.00s
# Tue Apr  8 13:16:11 2025 Epoch 15/99
# Epoch 15/100 Batch 0/641 Loss: 0.1108 Time: 48.33s
# Epoch 15/100 Batch 64/641 Loss: 0.1122 Time: 32.59s
# Epoch 15/100 Batch 128/641 Loss: 0.1116 Time: 32.69s
# Epoch 15/100 Batch 192/641 Loss: 0.1085 Time: 32.75s
# Epoch 15/100 Batch 256/641 Loss: 0.1071 Time: 32.77s
# Epoch 15/100 Batch 320/641 Loss: 0.1073 Time: 32.78s
# Epoch 15/100 Batch 384/641 Loss: 0.1070 Time: 32.77s
# Epoch 15/100 Batch 448/641 Loss: 0.1074 Time: 32.76s
# Epoch 15/100 Batch 512/641 Loss: 0.1073 Time: 32.78s
# Epoch 15/100 Batch 576/641 Loss: 0.1079 Time: 32.78s
# Epoch 15/100 Batch 640/641 Loss: 0.1077 Time: 32.78s
# Training 15/99 - Loss: 0.1077 - Time: 377.12s
# Tue Apr  8 13:22:28 2025 Epoch 16/99
# Epoch 16/100 Batch 0/641 Loss: 0.1114 Time: 49.29s
# Epoch 16/100 Batch 64/641 Loss: 0.1076 Time: 32.62s
# Epoch 16/100 Batch 128/641 Loss: 0.1060 Time: 32.74s
# Epoch 16/100 Batch 192/641 Loss: 0.1052 Time: 32.80s
# Epoch 16/100 Batch 256/641 Loss: 0.1050 Time: 32.86s
# Epoch 16/100 Batch 320/641 Loss: 0.1053 Time: 32.80s
# Epoch 16/100 Batch 384/641 Loss: 0.1057 Time: 32.79s
# Epoch 16/100 Batch 448/641 Loss: 0.1060 Time: 32.78s
# Epoch 16/100 Batch 512/641 Loss: 0.1056 Time: 32.78s
# Epoch 16/100 Batch 576/641 Loss: 0.1058 Time: 32.79s
# Epoch 16/100 Batch 640/641 Loss: 0.1061 Time: 32.79s
# Training 16/99 - Loss: 0.1061 - Time: 378.33s
# Tue Apr  8 13:28:47 2025 Epoch 17/99
# Epoch 17/100 Batch 0/641 Loss: 0.1468 Time: 47.82s
# Epoch 17/100 Batch 64/641 Loss: 0.1033 Time: 32.59s
# Epoch 17/100 Batch 128/641 Loss: 0.1026 Time: 32.65s
# Epoch 17/100 Batch 192/641 Loss: 0.1043 Time: 32.66s
# Epoch 17/100 Batch 256/641 Loss: 0.1048 Time: 32.80s
# Epoch 17/100 Batch 320/641 Loss: 0.1055 Time: 32.79s
# Epoch 17/100 Batch 384/641 Loss: 0.1053 Time: 32.90s
# Epoch 17/100 Batch 448/641 Loss: 0.1048 Time: 32.79s
# Epoch 17/100 Batch 512/641 Loss: 0.1051 Time: 32.79s
# Epoch 17/100 Batch 576/641 Loss: 0.1049 Time: 32.81s
# Epoch 17/100 Batch 640/641 Loss: 0.1051 Time: 32.81s
# Training 17/99 - Loss: 0.1051 - Time: 376.76s
# Tue Apr  8 13:35:04 2025 Epoch 18/99
# Epoch 18/100 Batch 0/641 Loss: 0.0863 Time: 47.93s
# Epoch 18/100 Batch 64/641 Loss: 0.1060 Time: 32.58s
# Epoch 18/100 Batch 128/641 Loss: 0.1012 Time: 32.68s
# Epoch 18/100 Batch 192/641 Loss: 0.1017 Time: 32.74s
# Epoch 18/100 Batch 256/641 Loss: 0.1035 Time: 32.87s
# Epoch 18/100 Batch 320/641 Loss: 0.1038 Time: 32.75s
# Epoch 18/100 Batch 384/641 Loss: 0.1030 Time: 32.78s
# Epoch 18/100 Batch 448/641 Loss: 0.1030 Time: 32.76s
# Epoch 18/100 Batch 512/641 Loss: 0.1038 Time: 32.77s
# Epoch 18/100 Batch 576/641 Loss: 0.1041 Time: 32.75s
# Epoch 18/100 Batch 640/641 Loss: 0.1044 Time: 32.76s
# Training 18/99 - Loss: 0.1044 - Time: 376.67s
# Tue Apr  8 13:41:20 2025 Epoch 19/99
# Epoch 19/100 Batch 0/641 Loss: 0.1068 Time: 47.55s
# Epoch 19/100 Batch 64/641 Loss: 0.0974 Time: 33.05s
# Epoch 19/100 Batch 128/641 Loss: 0.0982 Time: 32.66s
# Epoch 19/100 Batch 192/641 Loss: 0.1007 Time: 32.76s
# Epoch 19/100 Batch 256/641 Loss: 0.0999 Time: 32.78s
# Epoch 19/100 Batch 320/641 Loss: 0.1003 Time: 32.79s
# Epoch 19/100 Batch 384/641 Loss: 0.1009 Time: 32.78s
# Epoch 19/100 Batch 448/641 Loss: 0.1014 Time: 32.78s
# Epoch 19/100 Batch 512/641 Loss: 0.1022 Time: 32.80s
# Epoch 19/100 Batch 576/641 Loss: 0.1026 Time: 32.78s
# Epoch 19/100 Batch 640/641 Loss: 0.1029 Time: 32.80s
# Training 19/99 - Loss: 0.1029 - Time: 376.83s
# Validation 19/100 Batch 0/160 Dice_TC: 0.8842 Time: 9.39s
# Validation 19/100 Batch 16/160 Dice_TC: 0.8975 Time: 3.46s
# Validation 19/100 Batch 32/160 Dice_TC: 0.8998 Time: 3.42s
# Validation 19/100 Batch 48/160 Dice_TC: 0.9007 Time: 3.48s
# Validation 19/100 Batch 64/160 Dice_TC: 0.8987 Time: 2.80s
# Validation 19/100 Batch 80/160 Dice_TC: 0.9010 Time: 3.19s
# Validation 19/100 Batch 96/160 Dice_TC: 0.9012 Time: 3.04s
# Validation 19/100 Batch 112/160 Dice_TC: 0.9013 Time: 3.60s
# Validation 19/100 Batch 128/160 Dice_TC: 0.9018 Time: 3.34s
# Validation 19/100 Batch 144/160 Dice_TC: 0.9004 Time: 2.97s
# Validation 19/99 - Avg Dice: 0.9006 - Time: 41.75s
# New Best Accuracy: 0.8999 --> 0.9006
# Saved Best Model to best_model.pth
# Tue Apr  8 13:48:19 2025 Epoch 20/99
# Epoch 20/100 Batch 0/641 Loss: 0.0969 Time: 47.99s
# Epoch 20/100 Batch 64/641 Loss: 0.1033 Time: 32.55s
# Epoch 20/100 Batch 128/641 Loss: 0.1028 Time: 32.76s
# Epoch 20/100 Batch 192/641 Loss: 0.1022 Time: 32.70s
# Epoch 20/100 Batch 256/641 Loss: 0.1026 Time: 32.72s
# Epoch 20/100 Batch 320/641 Loss: 0.1033 Time: 32.73s
# Epoch 20/100 Batch 384/641 Loss: 0.1020 Time: 32.73s
# Epoch 20/100 Batch 448/641 Loss: 0.1019 Time: 32.73s
# Epoch 20/100 Batch 512/641 Loss: 0.1025 Time: 32.73s
# Epoch 20/100 Batch 576/641 Loss: 0.1029 Time: 32.73s
# Epoch 20/100 Batch 640/641 Loss: 0.1027 Time: 32.73s
# Training 20/99 - Loss: 0.1027 - Time: 376.43s
# Tue Apr  8 13:54:35 2025 Epoch 21/99
# Epoch 21/100 Batch 0/641 Loss: 0.1131 Time: 48.43s
# Epoch 21/100 Batch 64/641 Loss: 0.1037 Time: 32.58s
# Epoch 21/100 Batch 128/641 Loss: 0.1056 Time: 32.67s
# Epoch 21/100 Batch 192/641 Loss: 0.1049 Time: 32.76s
# Epoch 21/100 Batch 256/641 Loss: 0.1032 Time: 32.78s
# Epoch 21/100 Batch 320/641 Loss: 0.1019 Time: 32.79s
# Epoch 21/100 Batch 384/641 Loss: 0.1017 Time: 32.79s
# Epoch 21/100 Batch 448/641 Loss: 0.1015 Time: 32.79s
# Epoch 21/100 Batch 512/641 Loss: 0.1017 Time: 32.79s
# Epoch 21/100 Batch 576/641 Loss: 0.1015 Time: 32.79s
# Epoch 21/100 Batch 640/641 Loss: 0.1015 Time: 32.78s
# Training 21/99 - Loss: 0.1015 - Time: 377.31s
# Tue Apr  8 14:00:53 2025 Epoch 22/99
# Epoch 22/100 Batch 0/641 Loss: 0.0876 Time: 48.38s
# Epoch 22/100 Batch 64/641 Loss: 0.0973 Time: 32.59s
# Epoch 22/100 Batch 128/641 Loss: 0.0993 Time: 32.68s
# Epoch 22/100 Batch 192/641 Loss: 0.1018 Time: 32.72s
# Epoch 22/100 Batch 256/641 Loss: 0.1012 Time: 32.73s
# Epoch 22/100 Batch 320/641 Loss: 0.1007 Time: 32.72s
# Epoch 22/100 Batch 384/641 Loss: 0.1002 Time: 32.73s
# Epoch 22/100 Batch 448/641 Loss: 0.1003 Time: 32.75s
# Epoch 22/100 Batch 512/641 Loss: 0.1005 Time: 32.73s
# Epoch 22/100 Batch 576/641 Loss: 0.1005 Time: 32.74s
# Epoch 22/100 Batch 640/641 Loss: 0.1006 Time: 32.72s
# Training 22/99 - Loss: 0.1006 - Time: 376.79s
# Tue Apr  8 14:07:09 2025 Epoch 23/99
# Epoch 23/100 Batch 0/641 Loss: 0.1007 Time: 47.90s
# Epoch 23/100 Batch 64/641 Loss: 0.0953 Time: 32.59s
# Epoch 23/100 Batch 128/641 Loss: 0.0967 Time: 32.67s
# Epoch 23/100 Batch 192/641 Loss: 0.0982 Time: 32.74s
# Epoch 23/100 Batch 256/641 Loss: 0.0990 Time: 32.75s
# Epoch 23/100 Batch 320/641 Loss: 0.0988 Time: 32.77s
# Epoch 23/100 Batch 384/641 Loss: 0.0986 Time: 32.85s
# Epoch 23/100 Batch 448/641 Loss: 0.0987 Time: 32.75s
# Epoch 23/100 Batch 512/641 Loss: 0.0990 Time: 32.77s
# Epoch 23/100 Batch 576/641 Loss: 0.0994 Time: 32.78s
# Epoch 23/100 Batch 640/641 Loss: 0.0994 Time: 32.76s
# Training 23/99 - Loss: 0.0994 - Time: 376.62s
# Tue Apr  8 14:13:26 2025 Epoch 24/99
# Epoch 24/100 Batch 0/641 Loss: 0.0777 Time: 48.14s
# Epoch 24/100 Batch 64/641 Loss: 0.1011 Time: 32.59s
# Epoch 24/100 Batch 128/641 Loss: 0.1012 Time: 32.66s
# Epoch 24/100 Batch 192/641 Loss: 0.1018 Time: 32.76s
# Epoch 24/100 Batch 256/641 Loss: 0.1012 Time: 32.98s
# Epoch 24/100 Batch 320/641 Loss: 0.1007 Time: 32.95s
# Epoch 24/100 Batch 384/641 Loss: 0.1007 Time: 32.85s
# Epoch 24/100 Batch 448/641 Loss: 0.1003 Time: 32.83s
# Epoch 24/100 Batch 512/641 Loss: 0.0998 Time: 32.85s
# Epoch 24/100 Batch 576/641 Loss: 0.0992 Time: 32.85s
# Epoch 24/100 Batch 640/641 Loss: 0.0988 Time: 32.82s
# Training 24/99 - Loss: 0.0988 - Time: 377.65s
# Validation 24/100 Batch 0/160 Dice_TC: 0.8857 Time: 9.38s
# Validation 24/100 Batch 16/160 Dice_TC: 0.8988 Time: 3.60s
# Validation 24/100 Batch 32/160 Dice_TC: 0.8996 Time: 3.59s
# Validation 24/100 Batch 48/160 Dice_TC: 0.8998 Time: 3.39s
# Validation 24/100 Batch 64/160 Dice_TC: 0.8981 Time: 3.08s
# Validation 24/100 Batch 80/160 Dice_TC: 0.9008 Time: 3.05s
# Validation 24/100 Batch 96/160 Dice_TC: 0.9009 Time: 3.03s
# Validation 24/100 Batch 112/160 Dice_TC: 0.9011 Time: 3.72s
# Validation 24/100 Batch 128/160 Dice_TC: 0.9018 Time: 3.10s
# Validation 24/100 Batch 144/160 Dice_TC: 0.9008 Time: 3.32s
# Validation 24/99 - Avg Dice: 0.9006 - Time: 42.38s
# New Best Accuracy: 0.9006 --> 0.9006
# Saved Best Model to best_model.pth
# Tue Apr  8 14:20:26 2025 Epoch 25/99
# Epoch 25/100 Batch 0/641 Loss: 0.0903 Time: 48.57s
# Epoch 25/100 Batch 64/641 Loss: 0.0986 Time: 32.60s
# Epoch 25/100 Batch 128/641 Loss: 0.0980 Time: 32.70s
# Epoch 25/100 Batch 192/641 Loss: 0.0974 Time: 32.80s
# Epoch 25/100 Batch 256/641 Loss: 0.0976 Time: 32.77s
# Epoch 25/100 Batch 320/641 Loss: 0.0972 Time: 32.76s
# Epoch 25/100 Batch 384/641 Loss: 0.0982 Time: 32.78s
# Epoch 25/100 Batch 448/641 Loss: 0.0985 Time: 32.79s
# Epoch 25/100 Batch 512/641 Loss: 0.0982 Time: 32.78s
# Epoch 25/100 Batch 576/641 Loss: 0.0986 Time: 32.80s
# Epoch 25/100 Batch 640/641 Loss: 0.0981 Time: 32.96s
# Training 25/99 - Loss: 0.0981 - Time: 377.65s
# Tue Apr  8 14:26:44 2025 Epoch 26/99
# Epoch 26/100 Batch 0/641 Loss: 0.0784 Time: 48.76s
# Epoch 26/100 Batch 64/641 Loss: 0.0984 Time: 32.65s
# Epoch 26/100 Batch 128/641 Loss: 0.0965 Time: 32.74s
# Epoch 26/100 Batch 192/641 Loss: 0.0964 Time: 32.82s
# Epoch 26/100 Batch 256/641 Loss: 0.0955 Time: 32.82s
# Epoch 26/100 Batch 320/641 Loss: 0.0957 Time: 32.84s
# Epoch 26/100 Batch 384/641 Loss: 0.0966 Time: 32.82s
# Epoch 26/100 Batch 448/641 Loss: 0.0965 Time: 32.83s
# Epoch 26/100 Batch 512/641 Loss: 0.0969 Time: 32.83s
# Epoch 26/100 Batch 576/641 Loss: 0.0968 Time: 32.84s
# Epoch 26/100 Batch 640/641 Loss: 0.0970 Time: 32.83s
# Training 26/99 - Loss: 0.0970 - Time: 378.14s
# Tue Apr  8 14:33:02 2025 Epoch 27/99
# Epoch 27/100 Batch 0/641 Loss: 0.0922 Time: 48.32s
# Epoch 27/100 Batch 64/641 Loss: 0.0923 Time: 32.63s
# Epoch 27/100 Batch 128/641 Loss: 0.0930 Time: 32.71s
# Epoch 27/100 Batch 192/641 Loss: 0.0942 Time: 32.82s
# Epoch 27/100 Batch 256/641 Loss: 0.0944 Time: 32.89s
# Epoch 27/100 Batch 320/641 Loss: 0.0947 Time: 33.34s
# Epoch 27/100 Batch 384/641 Loss: 0.0954 Time: 32.87s
# Epoch 27/100 Batch 448/641 Loss: 0.0961 Time: 32.88s
# Epoch 27/100 Batch 512/641 Loss: 0.0965 Time: 32.87s
# Epoch 27/100 Batch 576/641 Loss: 0.0962 Time: 32.87s
# Epoch 27/100 Batch 640/641 Loss: 0.0960 Time: 32.88s
# Training 27/99 - Loss: 0.0960 - Time: 378.46s
# Tue Apr  8 14:39:20 2025 Epoch 28/99
# Epoch 28/100 Batch 0/641 Loss: 0.0692 Time: 48.54s
# Epoch 28/100 Batch 64/641 Loss: 0.0966 Time: 32.65s
# Epoch 28/100 Batch 128/641 Loss: 0.0975 Time: 32.78s
# Epoch 28/100 Batch 192/641 Loss: 0.0956 Time: 32.87s
# Epoch 28/100 Batch 256/641 Loss: 0.0951 Time: 33.14s
# Epoch 28/100 Batch 320/641 Loss: 0.0955 Time: 33.33s
# Epoch 28/100 Batch 384/641 Loss: 0.0957 Time: 33.35s
# Epoch 28/100 Batch 448/641 Loss: 0.0948 Time: 32.96s
# Epoch 28/100 Batch 512/641 Loss: 0.0946 Time: 32.87s
# Epoch 28/100 Batch 576/641 Loss: 0.0948 Time: 32.74s
# Epoch 28/100 Batch 640/641 Loss: 0.0950 Time: 32.78s
# Training 28/99 - Loss: 0.0950 - Time: 379.34s
# Tue Apr  8 14:45:40 2025 Epoch 29/99
# Epoch 29/100 Batch 0/641 Loss: 0.1301 Time: 49.07s
# Epoch 29/100 Batch 64/641 Loss: 0.0912 Time: 32.61s
# Epoch 29/100 Batch 128/641 Loss: 0.0917 Time: 32.70s
# Epoch 29/100 Batch 192/641 Loss: 0.0937 Time: 32.79s
# Epoch 29/100 Batch 256/641 Loss: 0.0930 Time: 32.80s
# Epoch 29/100 Batch 320/641 Loss: 0.0924 Time: 32.79s
# Epoch 29/100 Batch 384/641 Loss: 0.0924 Time: 32.80s
# Epoch 29/100 Batch 448/641 Loss: 0.0930 Time: 32.79s
# Epoch 29/100 Batch 512/641 Loss: 0.0935 Time: 32.81s
# Epoch 29/100 Batch 576/641 Loss: 0.0940 Time: 32.80s
# Epoch 29/100 Batch 640/641 Loss: 0.0942 Time: 32.80s
# Training 29/99 - Loss: 0.0942 - Time: 378.15s
# Validation 29/100 Batch 0/160 Dice_TC: 0.8879 Time: 9.02s
# Validation 29/100 Batch 16/160 Dice_TC: 0.9043 Time: 3.95s
# Validation 29/100 Batch 32/160 Dice_TC: 0.9060 Time: 3.53s
# Validation 29/100 Batch 48/160 Dice_TC: 0.9055 Time: 3.45s
# Validation 29/100 Batch 64/160 Dice_TC: 0.9038 Time: 2.69s
# Validation 29/100 Batch 80/160 Dice_TC: 0.9058 Time: 3.30s
# Validation 29/100 Batch 96/160 Dice_TC: 0.9057 Time: 3.23s
# Validation 29/100 Batch 112/160 Dice_TC: 0.9058 Time: 3.93s
# Validation 29/100 Batch 128/160 Dice_TC: 0.9063 Time: 3.30s
# Validation 29/100 Batch 144/160 Dice_TC: 0.9052 Time: 3.25s
# Validation 29/99 - Avg Dice: 0.9049 - Time: 42.83s
# New Best Accuracy: 0.9006 --> 0.9049
# Saved Best Model to best_model.pth
# Tue Apr  8 14:52:41 2025 Epoch 30/99
# Epoch 30/100 Batch 0/641 Loss: 0.0987 Time: 49.55s
# Epoch 30/100 Batch 64/641 Loss: 0.0927 Time: 32.73s
# Epoch 30/100 Batch 128/641 Loss: 0.0918 Time: 33.10s
# Epoch 30/100 Batch 192/641 Loss: 0.0925 Time: 33.05s
# Epoch 30/100 Batch 256/641 Loss: 0.0927 Time: 33.16s
# Epoch 30/100 Batch 320/641 Loss: 0.0930 Time: 33.16s
# Epoch 30/100 Batch 384/641 Loss: 0.0928 Time: 33.17s
# Epoch 30/100 Batch 448/641 Loss: 0.0926 Time: 32.92s
# Epoch 30/100 Batch 512/641 Loss: 0.0926 Time: 32.89s
# Epoch 30/100 Batch 576/641 Loss: 0.0929 Time: 33.13s
# Epoch 30/100 Batch 640/641 Loss: 0.0933 Time: 32.84s
# Training 30/99 - Loss: 0.0933 - Time: 381.03s
# Tue Apr  8 14:59:02 2025 Epoch 31/99
# Epoch 31/100 Batch 0/641 Loss: 0.1282 Time: 48.17s
# Epoch 31/100 Batch 64/641 Loss: 0.0934 Time: 32.65s
# Epoch 31/100 Batch 128/641 Loss: 0.0906 Time: 32.72s
# Epoch 31/100 Batch 192/641 Loss: 0.0928 Time: 32.73s
# Epoch 31/100 Batch 256/641 Loss: 0.0929 Time: 32.82s
# Epoch 31/100 Batch 320/641 Loss: 0.0923 Time: 32.87s
# Epoch 31/100 Batch 384/641 Loss: 0.0924 Time: 32.89s
# Epoch 31/100 Batch 448/641 Loss: 0.0924 Time: 32.88s
# Epoch 31/100 Batch 512/641 Loss: 0.0922 Time: 32.91s
# Epoch 31/100 Batch 576/641 Loss: 0.0923 Time: 32.88s
# Epoch 31/100 Batch 640/641 Loss: 0.0925 Time: 32.88s
# Training 31/99 - Loss: 0.0925 - Time: 377.71s
# Tue Apr  8 15:05:19 2025 Epoch 32/99
# Epoch 32/100 Batch 0/641 Loss: 0.1130 Time: 49.73s
# Epoch 32/100 Batch 64/641 Loss: 0.0935 Time: 32.65s
# Epoch 32/100 Batch 128/641 Loss: 0.0931 Time: 32.74s
# Epoch 32/100 Batch 192/641 Loss: 0.0930 Time: 32.88s
# Epoch 32/100 Batch 256/641 Loss: 0.0920 Time: 32.83s
# Epoch 32/100 Batch 320/641 Loss: 0.0916 Time: 32.83s
# Epoch 32/100 Batch 384/641 Loss: 0.0913 Time: 32.85s
# Epoch 32/100 Batch 448/641 Loss: 0.0913 Time: 32.84s
# Epoch 32/100 Batch 512/641 Loss: 0.0916 Time: 32.83s
# Epoch 32/100 Batch 576/641 Loss: 0.0918 Time: 32.85s
# Epoch 32/100 Batch 640/641 Loss: 0.0916 Time: 32.83s
# Training 32/99 - Loss: 0.0916 - Time: 379.21s
# Tue Apr  8 15:11:39 2025 Epoch 33/99
# Epoch 33/100 Batch 0/641 Loss: 0.0943 Time: 49.00s
# Epoch 33/100 Batch 64/641 Loss: 0.0921 Time: 32.65s
# Epoch 33/100 Batch 128/641 Loss: 0.0895 Time: 32.75s
# Epoch 33/100 Batch 192/641 Loss: 0.0884 Time: 32.81s
# Epoch 33/100 Batch 256/641 Loss: 0.0893 Time: 32.84s
# Epoch 33/100 Batch 320/641 Loss: 0.0905 Time: 32.83s
# Epoch 33/100 Batch 384/641 Loss: 0.0903 Time: 32.85s
# Epoch 33/100 Batch 448/641 Loss: 0.0905 Time: 32.87s
# Epoch 33/100 Batch 512/641 Loss: 0.0908 Time: 32.80s
# Epoch 33/100 Batch 576/641 Loss: 0.0909 Time: 32.80s
# Epoch 33/100 Batch 640/641 Loss: 0.0909 Time: 32.79s
# Training 33/99 - Loss: 0.0909 - Time: 378.36s
# Tue Apr  8 15:17:57 2025 Epoch 34/99
# Epoch 34/100 Batch 0/641 Loss: 0.0908 Time: 49.13s
# Epoch 34/100 Batch 64/641 Loss: 0.0898 Time: 32.97s
# Epoch 34/100 Batch 128/641 Loss: 0.0899 Time: 33.01s
# Epoch 34/100 Batch 192/641 Loss: 0.0903 Time: 32.84s
# Epoch 34/100 Batch 256/641 Loss: 0.0901 Time: 33.00s
# Epoch 34/100 Batch 320/641 Loss: 0.0901 Time: 32.84s
# Epoch 34/100 Batch 384/641 Loss: 0.0909 Time: 32.83s
# Epoch 34/100 Batch 448/641 Loss: 0.0899 Time: 32.85s
# Epoch 34/100 Batch 512/641 Loss: 0.0899 Time: 32.84s
# Epoch 34/100 Batch 576/641 Loss: 0.0900 Time: 32.85s
# Epoch 34/100 Batch 640/641 Loss: 0.0900 Time: 32.83s
# Training 34/99 - Loss: 0.0900 - Time: 379.34s
# Validation 34/100 Batch 0/160 Dice_TC: 0.8868 Time: 9.07s
# Validation 34/100 Batch 16/160 Dice_TC: 0.9001 Time: 3.60s
# Validation 34/100 Batch 32/160 Dice_TC: 0.9013 Time: 3.93s
# Validation 34/100 Batch 48/160 Dice_TC: 0.9018 Time: 3.08s
# Validation 34/100 Batch 64/160 Dice_TC: 0.9008 Time: 3.30s
# Validation 34/100 Batch 80/160 Dice_TC: 0.9027 Time: 3.09s
# Validation 34/100 Batch 96/160 Dice_TC: 0.9023 Time: 3.23s
# Validation 34/100 Batch 112/160 Dice_TC: 0.9023 Time: 3.14s
# Validation 34/100 Batch 128/160 Dice_TC: 0.9030 Time: 3.48s
# Validation 34/100 Batch 144/160 Dice_TC: 0.9019 Time: 3.18s
# Validation 34/99 - Avg Dice: 0.9014 - Time: 42.20s
# Tue Apr  8 15:24:58 2025 Epoch 35/99
# Epoch 35/100 Batch 0/641 Loss: 0.0892 Time: 48.65s
# Epoch 35/100 Batch 64/641 Loss: 0.0873 Time: 32.60s
# Epoch 35/100 Batch 128/641 Loss: 0.0882 Time: 32.73s
# Epoch 35/100 Batch 192/641 Loss: 0.0879 Time: 32.78s
# Epoch 35/100 Batch 256/641 Loss: 0.0881 Time: 32.78s
# Epoch 35/100 Batch 320/641 Loss: 0.0885 Time: 32.80s
# Epoch 35/100 Batch 384/641 Loss: 0.0884 Time: 32.80s
# Epoch 35/100 Batch 448/641 Loss: 0.0889 Time: 32.88s
# Epoch 35/100 Batch 512/641 Loss: 0.0893 Time: 32.82s
# Epoch 35/100 Batch 576/641 Loss: 0.0889 Time: 32.84s
# Epoch 35/100 Batch 640/641 Loss: 0.0886 Time: 32.76s
# Training 35/99 - Loss: 0.0886 - Time: 377.79s
# Tue Apr  8 15:31:16 2025 Epoch 36/99
# Epoch 36/100 Batch 0/641 Loss: 0.1239 Time: 48.71s
# Epoch 36/100 Batch 64/641 Loss: 0.0863 Time: 32.63s
# Epoch 36/100 Batch 128/641 Loss: 0.0854 Time: 32.70s
# Epoch 36/100 Batch 192/641 Loss: 0.0870 Time: 32.78s
# Epoch 36/100 Batch 256/641 Loss: 0.0878 Time: 32.79s
# Epoch 36/100 Batch 320/641 Loss: 0.0880 Time: 32.79s
# Epoch 36/100 Batch 384/641 Loss: 0.0876 Time: 32.89s
# Epoch 36/100 Batch 448/641 Loss: 0.0881 Time: 32.81s
# Epoch 36/100 Batch 512/641 Loss: 0.0884 Time: 32.79s
# Epoch 36/100 Batch 576/641 Loss: 0.0885 Time: 32.79s
# Epoch 36/100 Batch 640/641 Loss: 0.0883 Time: 32.80s
# Training 36/99 - Loss: 0.0883 - Time: 377.79s
# Tue Apr  8 15:37:34 2025 Epoch 37/99
# Epoch 37/100 Batch 0/641 Loss: 0.1000 Time: 48.01s
# Epoch 37/100 Batch 64/641 Loss: 0.0864 Time: 32.59s
# Epoch 37/100 Batch 128/641 Loss: 0.0867 Time: 32.68s
# Epoch 37/100 Batch 192/641 Loss: 0.0876 Time: 32.70s
# Epoch 37/100 Batch 256/641 Loss: 0.0872 Time: 32.79s
# Epoch 37/100 Batch 320/641 Loss: 0.0870 Time: 32.82s
# Epoch 37/100 Batch 384/641 Loss: 0.0874 Time: 32.82s
# Epoch 37/100 Batch 448/641 Loss: 0.0874 Time: 32.82s
# Epoch 37/100 Batch 512/641 Loss: 0.0874 Time: 32.82s
# Epoch 37/100 Batch 576/641 Loss: 0.0875 Time: 32.83s
# Epoch 37/100 Batch 640/641 Loss: 0.0873 Time: 32.81s
# Training 37/99 - Loss: 0.0873 - Time: 376.99s
# Tue Apr  8 15:43:51 2025 Epoch 38/99
# Epoch 38/100 Batch 0/641 Loss: 0.0788 Time: 48.49s
# Epoch 38/100 Batch 64/641 Loss: 0.0871 Time: 32.59s
# Epoch 38/100 Batch 128/641 Loss: 0.0866 Time: 32.70s
# Epoch 38/100 Batch 192/641 Loss: 0.0866 Time: 32.74s
# Epoch 38/100 Batch 256/641 Loss: 0.0855 Time: 32.74s
# Epoch 38/100 Batch 320/641 Loss: 0.0856 Time: 32.76s
# Epoch 38/100 Batch 384/641 Loss: 0.0852 Time: 32.77s
# Epoch 38/100 Batch 448/641 Loss: 0.0855 Time: 32.75s
# Epoch 38/100 Batch 512/641 Loss: 0.0865 Time: 32.76s
# Epoch 38/100 Batch 576/641 Loss: 0.0863 Time: 32.75s
# Epoch 38/100 Batch 640/641 Loss: 0.0864 Time: 32.75s
# Training 38/99 - Loss: 0.0864 - Time: 377.16s
# Tue Apr  8 15:50:08 2025 Epoch 39/99
# Epoch 39/100 Batch 0/641 Loss: 0.0908 Time: 48.00s
# Epoch 39/100 Batch 64/641 Loss: 0.0842 Time: 32.60s
# Epoch 39/100 Batch 128/641 Loss: 0.0835 Time: 32.71s
# Epoch 39/100 Batch 192/641 Loss: 0.0839 Time: 32.75s
# Epoch 39/100 Batch 256/641 Loss: 0.0847 Time: 32.75s
# Epoch 39/100 Batch 320/641 Loss: 0.0844 Time: 32.76s
# Epoch 39/100 Batch 384/641 Loss: 0.0848 Time: 32.76s
# Epoch 39/100 Batch 448/641 Loss: 0.0848 Time: 32.78s
# Epoch 39/100 Batch 512/641 Loss: 0.0850 Time: 32.76s
# Epoch 39/100 Batch 576/641 Loss: 0.0856 Time: 32.97s
# Epoch 39/100 Batch 640/641 Loss: 0.0856 Time: 32.79s
# Training 39/99 - Loss: 0.0856 - Time: 376.96s
# Validation 39/100 Batch 0/160 Dice_TC: 0.8766 Time: 9.34s
# Validation 39/100 Batch 16/160 Dice_TC: 0.9031 Time: 3.41s
# Validation 39/100 Batch 32/160 Dice_TC: 0.9061 Time: 3.72s
# Validation 39/100 Batch 48/160 Dice_TC: 0.9058 Time: 3.52s
# Validation 39/100 Batch 64/160 Dice_TC: 0.9027 Time: 2.69s
# Validation 39/100 Batch 80/160 Dice_TC: 0.9047 Time: 3.31s
# Validation 39/100 Batch 96/160 Dice_TC: 0.9044 Time: 2.93s
# Validation 39/100 Batch 112/160 Dice_TC: 0.9045 Time: 3.82s
# Validation 39/100 Batch 128/160 Dice_TC: 0.9051 Time: 3.30s
# Validation 39/100 Batch 144/160 Dice_TC: 0.9039 Time: 3.05s
# Validation 39/99 - Avg Dice: 0.9028 - Time: 42.22s
# Tue Apr  8 15:57:07 2025 Epoch 40/99
# Epoch 40/100 Batch 0/641 Loss: 0.1245 Time: 49.10s
# Epoch 40/100 Batch 64/641 Loss: 0.0869 Time: 32.62s
# Epoch 40/100 Batch 128/641 Loss: 0.0844 Time: 32.71s
# Epoch 40/100 Batch 192/641 Loss: 0.0849 Time: 32.82s
# Epoch 40/100 Batch 256/641 Loss: 0.0851 Time: 32.84s
# Epoch 40/100 Batch 320/641 Loss: 0.0848 Time: 32.83s
# Epoch 40/100 Batch 384/641 Loss: 0.0850 Time: 32.85s
# Epoch 40/100 Batch 448/641 Loss: 0.0849 Time: 32.83s
# Epoch 40/100 Batch 512/641 Loss: 0.0850 Time: 32.85s
# Epoch 40/100 Batch 576/641 Loss: 0.0851 Time: 32.84s
# Epoch 40/100 Batch 640/641 Loss: 0.0849 Time: 32.85s
# Training 40/99 - Loss: 0.0849 - Time: 378.48s
# Tue Apr  8 16:03:26 2025 Epoch 41/99
# Epoch 41/100 Batch 0/641 Loss: 0.0727 Time: 48.33s
# Epoch 41/100 Batch 64/641 Loss: 0.0801 Time: 32.67s
# Epoch 41/100 Batch 128/641 Loss: 0.0829 Time: 32.76s
# Epoch 41/100 Batch 192/641 Loss: 0.0839 Time: 32.73s
# Epoch 41/100 Batch 256/641 Loss: 0.0834 Time: 32.81s
# Epoch 41/100 Batch 320/641 Loss: 0.0839 Time: 32.81s
# Epoch 41/100 Batch 384/641 Loss: 0.0843 Time: 32.83s
# Epoch 41/100 Batch 448/641 Loss: 0.0843 Time: 32.82s
# Epoch 41/100 Batch 512/641 Loss: 0.0841 Time: 32.82s
# Epoch 41/100 Batch 576/641 Loss: 0.0840 Time: 32.82s
# Epoch 41/100 Batch 640/641 Loss: 0.0841 Time: 32.82s
# Training 41/99 - Loss: 0.0841 - Time: 377.58s
# Tue Apr  8 16:09:43 2025 Epoch 42/99
# Epoch 42/100 Batch 0/641 Loss: 0.0676 Time: 48.98s
# Epoch 42/100 Batch 64/641 Loss: 0.0834 Time: 32.58s
# Epoch 42/100 Batch 128/641 Loss: 0.0833 Time: 32.69s
# Epoch 42/100 Batch 192/641 Loss: 0.0832 Time: 32.74s
# Epoch 42/100 Batch 256/641 Loss: 0.0826 Time: 32.72s
# Epoch 42/100 Batch 320/641 Loss: 0.0825 Time: 32.84s
# Epoch 42/100 Batch 384/641 Loss: 0.0829 Time: 32.82s
# Epoch 42/100 Batch 448/641 Loss: 0.0832 Time: 32.83s
# Epoch 42/100 Batch 512/641 Loss: 0.0831 Time: 32.82s
# Epoch 42/100 Batch 576/641 Loss: 0.0832 Time: 32.82s
# Epoch 42/100 Batch 640/641 Loss: 0.0833 Time: 32.81s
# Training 42/99 - Loss: 0.0833 - Time: 377.99s
# Tue Apr  8 16:16:01 2025 Epoch 43/99
# Epoch 43/100 Batch 0/641 Loss: 0.0587 Time: 48.88s
# Epoch 43/100 Batch 64/641 Loss: 0.0794 Time: 32.61s
# Epoch 43/100 Batch 128/641 Loss: 0.0814 Time: 32.71s
# Epoch 43/100 Batch 192/641 Loss: 0.0810 Time: 32.78s
# Epoch 43/100 Batch 256/641 Loss: 0.0804 Time: 32.79s
# Epoch 43/100 Batch 320/641 Loss: 0.0811 Time: 32.79s
# Epoch 43/100 Batch 384/641 Loss: 0.0814 Time: 32.83s
# Epoch 43/100 Batch 448/641 Loss: 0.0817 Time: 32.80s
# Epoch 43/100 Batch 512/641 Loss: 0.0824 Time: 32.80s
# Epoch 43/100 Batch 576/641 Loss: 0.0826 Time: 32.80s
# Epoch 43/100 Batch 640/641 Loss: 0.0824 Time: 32.80s
# Training 43/99 - Loss: 0.0824 - Time: 377.91s
# Tue Apr  8 16:22:19 2025 Epoch 44/99
# Epoch 44/100 Batch 0/641 Loss: 0.0573 Time: 48.45s
# Epoch 44/100 Batch 64/641 Loss: 0.0793 Time: 32.61s
# Epoch 44/100 Batch 128/641 Loss: 0.0812 Time: 32.64s
# Epoch 44/100 Batch 192/641 Loss: 0.0813 Time: 32.77s
# Epoch 44/100 Batch 256/641 Loss: 0.0811 Time: 32.88s
# Epoch 44/100 Batch 320/641 Loss: 0.0815 Time: 32.81s
# Epoch 44/100 Batch 384/641 Loss: 0.0813 Time: 32.81s
# Epoch 44/100 Batch 448/641 Loss: 0.0812 Time: 32.80s
# Epoch 44/100 Batch 512/641 Loss: 0.0814 Time: 32.80s
# Epoch 44/100 Batch 576/641 Loss: 0.0819 Time: 32.81s
# Epoch 44/100 Batch 640/641 Loss: 0.0823 Time: 32.79s
# Training 44/99 - Loss: 0.0823 - Time: 377.52s
# Validation 44/100 Batch 0/160 Dice_TC: 0.8823 Time: 9.41s
# Validation 44/100 Batch 16/160 Dice_TC: 0.9025 Time: 3.24s
# Validation 44/100 Batch 32/160 Dice_TC: 0.9045 Time: 4.02s
# Validation 44/100 Batch 48/160 Dice_TC: 0.9051 Time: 3.08s
# Validation 44/100 Batch 64/160 Dice_TC: 0.9031 Time: 2.87s
# Validation 44/100 Batch 80/160 Dice_TC: 0.9051 Time: 3.20s
# Validation 44/100 Batch 96/160 Dice_TC: 0.9048 Time: 2.98s
# Validation 44/100 Batch 112/160 Dice_TC: 0.9046 Time: 3.74s
# Validation 44/100 Batch 128/160 Dice_TC: 0.9050 Time: 3.41s
# Validation 44/100 Batch 144/160 Dice_TC: 0.9038 Time: 3.01s
# Validation 44/99 - Avg Dice: 0.9036 - Time: 42.06s
# Tue Apr  8 16:29:19 2025 Epoch 45/99
# Epoch 45/100 Batch 0/641 Loss: 0.0951 Time: 48.32s
# Epoch 45/100 Batch 64/641 Loss: 0.0813 Time: 32.58s
# Epoch 45/100 Batch 128/641 Loss: 0.0819 Time: 32.67s
# Epoch 45/100 Batch 192/641 Loss: 0.0816 Time: 32.74s
# Epoch 45/100 Batch 256/641 Loss: 0.0817 Time: 32.77s
# Epoch 45/100 Batch 320/641 Loss: 0.0811 Time: 32.76s
# Epoch 45/100 Batch 384/641 Loss: 0.0811 Time: 32.76s
# Epoch 45/100 Batch 448/641 Loss: 0.0814 Time: 32.75s
# Epoch 45/100 Batch 512/641 Loss: 0.0810 Time: 32.77s
# Epoch 45/100 Batch 576/641 Loss: 0.0809 Time: 32.77s
# Epoch 45/100 Batch 640/641 Loss: 0.0811 Time: 32.76s
# Training 45/99 - Loss: 0.0811 - Time: 376.97s
# Tue Apr  8 16:35:36 2025 Epoch 46/99
# Epoch 46/100 Batch 0/641 Loss: 0.0845 Time: 48.82s
# Epoch 46/100 Batch 64/641 Loss: 0.0820 Time: 32.62s
# Epoch 46/100 Batch 128/641 Loss: 0.0799 Time: 32.69s
# Epoch 46/100 Batch 192/641 Loss: 0.0797 Time: 32.78s
# Epoch 46/100 Batch 256/641 Loss: 0.0791 Time: 32.79s
# Epoch 46/100 Batch 320/641 Loss: 0.0796 Time: 32.82s
# Epoch 46/100 Batch 384/641 Loss: 0.0798 Time: 32.80s
# Epoch 46/100 Batch 448/641 Loss: 0.0798 Time: 32.80s
# Epoch 46/100 Batch 512/641 Loss: 0.0800 Time: 32.80s
# Epoch 46/100 Batch 576/641 Loss: 0.0802 Time: 32.80s
# Epoch 46/100 Batch 640/641 Loss: 0.0804 Time: 32.80s
# Training 46/99 - Loss: 0.0804 - Time: 377.82s
# Tue Apr  8 16:41:54 2025 Epoch 47/99
# Epoch 47/100 Batch 0/641 Loss: 0.0873 Time: 48.47s
# Epoch 47/100 Batch 64/641 Loss: 0.0820 Time: 32.60s
# Epoch 47/100 Batch 128/641 Loss: 0.0802 Time: 32.65s
# Epoch 47/100 Batch 192/641 Loss: 0.0809 Time: 32.78s
# Epoch 47/100 Batch 256/641 Loss: 0.0805 Time: 32.79s
# Epoch 47/100 Batch 320/641 Loss: 0.0808 Time: 32.82s
# Epoch 47/100 Batch 384/641 Loss: 0.0804 Time: 32.82s
# Epoch 47/100 Batch 448/641 Loss: 0.0806 Time: 32.81s
# Epoch 47/100 Batch 512/641 Loss: 0.0807 Time: 32.81s
# Epoch 47/100 Batch 576/641 Loss: 0.0804 Time: 32.92s
# Epoch 47/100 Batch 640/641 Loss: 0.0801 Time: 32.81s
# Training 47/99 - Loss: 0.0801 - Time: 377.59s
# Tue Apr  8 16:48:11 2025 Epoch 48/99
# Epoch 48/100 Batch 0/641 Loss: 0.0754 Time: 48.14s
# Epoch 48/100 Batch 64/641 Loss: 0.0764 Time: 32.61s
# Epoch 48/100 Batch 128/641 Loss: 0.0788 Time: 32.70s
# Epoch 48/100 Batch 192/641 Loss: 0.0784 Time: 32.74s
# Epoch 48/100 Batch 256/641 Loss: 0.0792 Time: 32.74s
# Epoch 48/100 Batch 320/641 Loss: 0.0789 Time: 32.76s
# Epoch 48/100 Batch 384/641 Loss: 0.0792 Time: 32.75s
# Epoch 48/100 Batch 448/641 Loss: 0.0792 Time: 32.77s
# Epoch 48/100 Batch 512/641 Loss: 0.0793 Time: 32.76s
# Epoch 48/100 Batch 576/641 Loss: 0.0795 Time: 32.77s
# Epoch 48/100 Batch 640/641 Loss: 0.0794 Time: 32.76s
# Training 48/99 - Loss: 0.0794 - Time: 376.85s
# Tue Apr  8 16:54:28 2025 Epoch 49/99
# Epoch 49/100 Batch 0/641 Loss: 0.0652 Time: 48.57s
# Epoch 49/100 Batch 64/641 Loss: 0.0791 Time: 32.61s
# Epoch 49/100 Batch 128/641 Loss: 0.0779 Time: 32.71s
# Epoch 49/100 Batch 192/641 Loss: 0.0790 Time: 32.75s
# Epoch 49/100 Batch 256/641 Loss: 0.0787 Time: 32.76s
# Epoch 49/100 Batch 320/641 Loss: 0.0793 Time: 32.75s
# Epoch 49/100 Batch 384/641 Loss: 0.0794 Time: 32.78s
# Epoch 49/100 Batch 448/641 Loss: 0.0793 Time: 32.77s
# Epoch 49/100 Batch 512/641 Loss: 0.0791 Time: 32.83s
# Epoch 49/100 Batch 576/641 Loss: 0.0789 Time: 32.77s
# Epoch 49/100 Batch 640/641 Loss: 0.0786 Time: 32.75s
# Training 49/99 - Loss: 0.0786 - Time: 377.38s
# Validation 49/100 Batch 0/160 Dice_TC: 0.8906 Time: 9.69s
# Validation 49/100 Batch 16/160 Dice_TC: 0.9053 Time: 3.05s
# Validation 49/100 Batch 32/160 Dice_TC: 0.9070 Time: 3.83s
# Validation 49/100 Batch 48/160 Dice_TC: 0.9072 Time: 3.12s
# Validation 49/100 Batch 64/160 Dice_TC: 0.9050 Time: 3.28s
# Validation 49/100 Batch 80/160 Dice_TC: 0.9068 Time: 3.19s
# Validation 49/100 Batch 96/160 Dice_TC: 0.9066 Time: 3.12s
# Validation 49/100 Batch 112/160 Dice_TC: 0.9065 Time: 3.20s
# Validation 49/100 Batch 128/160 Dice_TC: 0.9070 Time: 3.37s
# Validation 49/100 Batch 144/160 Dice_TC: 0.9058 Time: 2.99s
# Validation 49/99 - Avg Dice: 0.9056 - Time: 42.09s
# New Best Accuracy: 0.9049 --> 0.9056
# Saved Best Model to best_model.pth
# Tue Apr  8 17:01:28 2025 Epoch 50/99
# Epoch 50/100 Batch 0/641 Loss: 0.0770 Time: 48.14s
# Epoch 50/100 Batch 64/641 Loss: 0.0792 Time: 32.59s
# Epoch 50/100 Batch 128/641 Loss: 0.0782 Time: 32.65s
# Epoch 50/100 Batch 192/641 Loss: 0.0776 Time: 32.74s
# Epoch 50/100 Batch 256/641 Loss: 0.0779 Time: 32.78s
# Epoch 50/100 Batch 320/641 Loss: 0.0781 Time: 32.80s
# Epoch 50/100 Batch 384/641 Loss: 0.0777 Time: 32.80s
# Epoch 50/100 Batch 448/641 Loss: 0.0778 Time: 32.81s
# Epoch 50/100 Batch 512/641 Loss: 0.0780 Time: 32.81s
# Epoch 50/100 Batch 576/641 Loss: 0.0779 Time: 32.79s
# Epoch 50/100 Batch 640/641 Loss: 0.0780 Time: 32.81s
# Training 50/99 - Loss: 0.0780 - Time: 377.02s
# Tue Apr  8 17:07:45 2025 Epoch 51/99
# Epoch 51/100 Batch 0/641 Loss: 0.0697 Time: 47.99s
# Epoch 51/100 Batch 64/641 Loss: 0.0752 Time: 32.94s
# Epoch 51/100 Batch 128/641 Loss: 0.0778 Time: 32.65s
# Epoch 51/100 Batch 192/641 Loss: 0.0772 Time: 32.72s
# Epoch 51/100 Batch 256/641 Loss: 0.0771 Time: 32.80s
# Epoch 51/100 Batch 320/641 Loss: 0.0771 Time: 32.81s
# Epoch 51/100 Batch 384/641 Loss: 0.0776 Time: 32.82s
# Epoch 51/100 Batch 448/641 Loss: 0.0780 Time: 32.81s
# Epoch 51/100 Batch 512/641 Loss: 0.0775 Time: 32.80s
# Epoch 51/100 Batch 576/641 Loss: 0.0775 Time: 32.81s
# Epoch 51/100 Batch 640/641 Loss: 0.0775 Time: 32.81s
# Training 51/99 - Loss: 0.0775 - Time: 377.29s
# Tue Apr  8 17:14:02 2025 Epoch 52/99
# Epoch 52/100 Batch 0/641 Loss: 0.0865 Time: 48.38s
# Epoch 52/100 Batch 64/641 Loss: 0.0772 Time: 32.59s
# Epoch 52/100 Batch 128/641 Loss: 0.0764 Time: 32.70s
# Epoch 52/100 Batch 192/641 Loss: 0.0770 Time: 32.70s
# Epoch 52/100 Batch 256/641 Loss: 0.0766 Time: 32.75s
# Epoch 52/100 Batch 320/641 Loss: 0.0767 Time: 32.83s
# Epoch 52/100 Batch 384/641 Loss: 0.0768 Time: 32.82s
# Epoch 52/100 Batch 448/641 Loss: 0.0767 Time: 32.84s
# Epoch 52/100 Batch 512/641 Loss: 0.0767 Time: 32.83s
# Epoch 52/100 Batch 576/641 Loss: 0.0766 Time: 32.86s
# Epoch 52/100 Batch 640/641 Loss: 0.0768 Time: 32.84s
# Training 52/99 - Loss: 0.0768 - Time: 377.47s
# Tue Apr  8 17:20:19 2025 Epoch 53/99
# Epoch 53/100 Batch 0/641 Loss: 0.0612 Time: 48.39s
# Epoch 53/100 Batch 64/641 Loss: 0.0757 Time: 32.55s
# Epoch 53/100 Batch 128/641 Loss: 0.0759 Time: 32.70s
# Epoch 53/100 Batch 192/641 Loss: 0.0760 Time: 32.73s
# Epoch 53/100 Batch 256/641 Loss: 0.0768 Time: 32.73s
# Epoch 53/100 Batch 320/641 Loss: 0.0766 Time: 32.75s
# Epoch 53/100 Batch 384/641 Loss: 0.0771 Time: 32.75s
# Epoch 53/100 Batch 448/641 Loss: 0.0774 Time: 32.74s
# Epoch 53/100 Batch 512/641 Loss: 0.0768 Time: 32.74s
# Epoch 53/100 Batch 576/641 Loss: 0.0768 Time: 32.86s
# Epoch 53/100 Batch 640/641 Loss: 0.0765 Time: 32.73s
# Training 53/99 - Loss: 0.0765 - Time: 377.04s
# Tue Apr  8 17:26:37 2025 Epoch 54/99
# Epoch 54/100 Batch 0/641 Loss: 0.0644 Time: 49.02s
# Epoch 54/100 Batch 64/641 Loss: 0.0764 Time: 32.60s
# Epoch 54/100 Batch 128/641 Loss: 0.0745 Time: 32.69s
# Epoch 54/100 Batch 192/641 Loss: 0.0746 Time: 32.76s
# Epoch 54/100 Batch 256/641 Loss: 0.0746 Time: 32.75s
# Epoch 54/100 Batch 320/641 Loss: 0.0750 Time: 32.77s
# Epoch 54/100 Batch 384/641 Loss: 0.0755 Time: 32.75s
# Epoch 54/100 Batch 448/641 Loss: 0.0756 Time: 32.76s
# Epoch 54/100 Batch 512/641 Loss: 0.0755 Time: 32.80s
# Epoch 54/100 Batch 576/641 Loss: 0.0756 Time: 32.75s
# Epoch 54/100 Batch 640/641 Loss: 0.0758 Time: 32.76s
# Training 54/99 - Loss: 0.0758 - Time: 377.74s
# Validation 54/100 Batch 0/160 Dice_TC: 0.8739 Time: 9.15s
# Validation 54/100 Batch 16/160 Dice_TC: 0.9032 Time: 3.54s
# Validation 54/100 Batch 32/160 Dice_TC: 0.9053 Time: 4.07s
# Validation 54/100 Batch 48/160 Dice_TC: 0.9054 Time: 2.68s
# Validation 54/100 Batch 64/160 Dice_TC: 0.9029 Time: 3.65s
# Validation 54/100 Batch 80/160 Dice_TC: 0.9049 Time: 3.16s
# Validation 54/100 Batch 96/160 Dice_TC: 0.9048 Time: 2.97s
# Validation 54/100 Batch 112/160 Dice_TC: 0.9047 Time: 3.29s
# Validation 54/100 Batch 128/160 Dice_TC: 0.9052 Time: 3.23s
# Validation 54/100 Batch 144/160 Dice_TC: 0.9038 Time: 3.16s
# Validation 54/99 - Avg Dice: 0.9036 - Time: 42.23s
# Tue Apr  8 17:33:36 2025 Epoch 55/99
# Epoch 55/100 Batch 0/641 Loss: 0.0720 Time: 48.30s
# Epoch 55/100 Batch 64/641 Loss: 0.0745 Time: 32.70s
# Epoch 55/100 Batch 128/641 Loss: 0.0745 Time: 32.66s
# Epoch 55/100 Batch 192/641 Loss: 0.0736 Time: 32.73s
# Epoch 55/100 Batch 256/641 Loss: 0.0741 Time: 32.74s
# Epoch 55/100 Batch 320/641 Loss: 0.0745 Time: 32.82s
# Epoch 55/100 Batch 384/641 Loss: 0.0747 Time: 32.76s
# Epoch 55/100 Batch 448/641 Loss: 0.0749 Time: 32.75s
# Epoch 55/100 Batch 512/641 Loss: 0.0753 Time: 32.74s
# Epoch 55/100 Batch 576/641 Loss: 0.0754 Time: 32.76s
# Epoch 55/100 Batch 640/641 Loss: 0.0753 Time: 32.75s
# Training 55/99 - Loss: 0.0753 - Time: 377.07s
# Tue Apr  8 17:39:54 2025 Epoch 56/99
# Epoch 56/100 Batch 0/641 Loss: 0.0622 Time: 49.30s
# Epoch 56/100 Batch 64/641 Loss: 0.0735 Time: 32.60s
# Epoch 56/100 Batch 128/641 Loss: 0.0738 Time: 32.68s
# Epoch 56/100 Batch 192/641 Loss: 0.0739 Time: 32.78s
# Epoch 56/100 Batch 256/641 Loss: 0.0744 Time: 32.78s
# Epoch 56/100 Batch 320/641 Loss: 0.0747 Time: 32.80s
# Epoch 56/100 Batch 384/641 Loss: 0.0749 Time: 32.80s
# Epoch 56/100 Batch 448/641 Loss: 0.0746 Time: 32.79s
# Epoch 56/100 Batch 512/641 Loss: 0.0743 Time: 32.79s
# Epoch 56/100 Batch 576/641 Loss: 0.0746 Time: 32.80s
# Epoch 56/100 Batch 640/641 Loss: 0.0747 Time: 32.78s
# Training 56/99 - Loss: 0.0747 - Time: 378.25s
# Tue Apr  8 17:46:12 2025 Epoch 57/99
# Epoch 57/100 Batch 0/641 Loss: 0.0748 Time: 49.74s
# Epoch 57/100 Batch 64/641 Loss: 0.0759 Time: 32.59s
# Epoch 57/100 Batch 128/641 Loss: 0.0737 Time: 32.68s
# Epoch 57/100 Batch 192/641 Loss: 0.0736 Time: 32.71s
# Epoch 57/100 Batch 256/641 Loss: 0.0738 Time: 32.79s
# Epoch 57/100 Batch 320/641 Loss: 0.0739 Time: 32.82s
# Epoch 57/100 Batch 384/641 Loss: 0.0739 Time: 32.83s
# Epoch 57/100 Batch 448/641 Loss: 0.0742 Time: 32.84s
# Epoch 57/100 Batch 512/641 Loss: 0.0742 Time: 32.84s
# Epoch 57/100 Batch 576/641 Loss: 0.0739 Time: 32.83s
# Epoch 57/100 Batch 640/641 Loss: 0.0742 Time: 32.83s
# Training 57/99 - Loss: 0.0742 - Time: 378.84s
# Tue Apr  8 17:52:31 2025 Epoch 58/99
# Epoch 58/100 Batch 0/641 Loss: 0.0712 Time: 48.76s
# Epoch 58/100 Batch 64/641 Loss: 0.0714 Time: 32.60s
# Epoch 58/100 Batch 128/641 Loss: 0.0737 Time: 32.69s
# Epoch 58/100 Batch 192/641 Loss: 0.0735 Time: 32.78s
# Epoch 58/100 Batch 256/641 Loss: 0.0734 Time: 32.77s
# Epoch 58/100 Batch 320/641 Loss: 0.0728 Time: 32.80s
# Epoch 58/100 Batch 384/641 Loss: 0.0728 Time: 32.80s
# Epoch 58/100 Batch 448/641 Loss: 0.0732 Time: 32.80s
# Epoch 58/100 Batch 512/641 Loss: 0.0731 Time: 32.80s
# Epoch 58/100 Batch 576/641 Loss: 0.0737 Time: 32.80s
# Epoch 58/100 Batch 640/641 Loss: 0.0740 Time: 32.78s
# Training 58/99 - Loss: 0.0740 - Time: 377.77s
# Tue Apr  8 17:58:48 2025 Epoch 59/99
# Epoch 59/100 Batch 0/641 Loss: 0.0590 Time: 48.48s
# Epoch 59/100 Batch 64/641 Loss: 0.0705 Time: 32.59s
# Epoch 59/100 Batch 128/641 Loss: 0.0726 Time: 32.64s
# Epoch 59/100 Batch 192/641 Loss: 0.0730 Time: 32.73s
# Epoch 59/100 Batch 256/641 Loss: 0.0728 Time: 32.80s
# Epoch 59/100 Batch 320/641 Loss: 0.0729 Time: 32.79s
# Epoch 59/100 Batch 384/641 Loss: 0.0727 Time: 32.80s
# Epoch 59/100 Batch 448/641 Loss: 0.0730 Time: 32.81s
# Epoch 59/100 Batch 512/641 Loss: 0.0729 Time: 32.80s
# Epoch 59/100 Batch 576/641 Loss: 0.0736 Time: 32.80s
# Epoch 59/100 Batch 640/641 Loss: 0.0736 Time: 32.79s
# Training 59/99 - Loss: 0.0736 - Time: 377.40s
# Validation 59/100 Batch 0/160 Dice_TC: 0.8765 Time: 9.19s
# Validation 59/100 Batch 16/160 Dice_TC: 0.9037 Time: 3.86s
# ...
# Validation 79/100 Batch 144/160 Dice_TC: 0.9040 Time: 3.23s
# Validation 79/99 - Avg Dice: 0.9039 - Time: 42.80s
# Tue Apr  8 20:14:33 2025 Epoch 80/99
# Epoch 80/100 Batch 0/641 Loss: 0.0712 Time: 48.47s
# Epoch 80/100 Batch 64/641 Loss: 0.0668 Time: 32.59s
# Epoch 80/100 Batch 128/641 Loss: 0.0673 Time: 32.68s
# Epoch 80/100 Batch 192/641 Loss: 0.0668 Time: 32.72s
# Epoch 80/100 Batch 256/641 Loss: 0.0673 Time: 32.72s
# Epoch 80/100 Batch 320/641 Loss: 0.0672 Time: 32.74s
# Epoch 80/100 Batch 384/641 Loss: 0.0672 Time: 32.75s
# Epoch 80/100 Batch 448/641 Loss: 0.0671 Time: 32.74s
# Epoch 80/100 Batch 512/641 Loss: 0.0671 Time: 32.74s
# Epoch 80/100 Batch 576/641 Loss: 0.0672 Time: 32.75s
# Epoch 80/100 Batch 640/641 Loss: 0.0670 Time: 32.75s
# Training 80/99 - Loss: 0.0670 - Time: 376.96s
# Tue Apr  8 20:20:50 2025 Epoch 81/99
# Epoch 81/100 Batch 0/641 Loss: 0.0762 Time: 49.98s
# Epoch 81/100 Batch 64/641 Loss: 0.0666 Time: 32.60s
# Epoch 81/100 Batch 128/641 Loss: 0.0671 Time: 32.69s
# Epoch 81/100 Batch 192/641 Loss: 0.0671 Time: 32.78s
# Epoch 81/100 Batch 256/641 Loss: 0.0668 Time: 32.88s
# Epoch 81/100 Batch 320/641 Loss: 0.0665 Time: 32.78s
# Epoch 81/100 Batch 384/641 Loss: 0.0663 Time: 32.78s
# Epoch 81/100 Batch 448/641 Loss: 0.0667 Time: 32.80s
# Epoch 81/100 Batch 512/641 Loss: 0.0667 Time: 32.80s
# Epoch 81/100 Batch 576/641 Loss: 0.0667 Time: 32.81s
# Epoch 81/100 Batch 640/641 Loss: 0.0668 Time: 32.79s
# Training 81/99 - Loss: 0.0668 - Time: 379.06s
# Tue Apr  8 20:27:09 2025 Epoch 82/99
# Epoch 82/100 Batch 0/641 Loss: 0.0540 Time: 49.19s
# Epoch 82/100 Batch 64/641 Loss: 0.0656 Time: 32.59s
# Epoch 82/100 Batch 128/641 Loss: 0.0664 Time: 32.70s
# Epoch 82/100 Batch 192/641 Loss: 0.0658 Time: 32.84s
# Epoch 82/100 Batch 256/641 Loss: 0.0658 Time: 32.73s
# Epoch 82/100 Batch 320/641 Loss: 0.0658 Time: 32.72s
# Epoch 82/100 Batch 384/641 Loss: 0.0663 Time: 32.76s
# Epoch 82/100 Batch 448/641 Loss: 0.0664 Time: 32.79s
# Epoch 82/100 Batch 512/641 Loss: 0.0667 Time: 32.83s
# Epoch 82/100 Batch 576/641 Loss: 0.0667 Time: 32.82s
# Epoch 82/100 Batch 640/641 Loss: 0.0667 Time: 32.81s
# Training 82/99 - Loss: 0.0667 - Time: 378.12s
# Tue Apr  8 20:33:27 2025 Epoch 83/99
# Epoch 83/100 Batch 0/641 Loss: 0.0517 Time: 48.57s
# Epoch 83/100 Batch 64/641 Loss: 0.0664 Time: 32.61s
# Epoch 83/100 Batch 128/641 Loss: 0.0669 Time: 32.69s
# Epoch 83/100 Batch 192/641 Loss: 0.0665 Time: 32.77s
# Epoch 83/100 Batch 256/641 Loss: 0.0665 Time: 32.80s
# Epoch 83/100 Batch 320/641 Loss: 0.0668 Time: 32.80s
# Epoch 83/100 Batch 384/641 Loss: 0.0666 Time: 32.79s
# Epoch 83/100 Batch 448/641 Loss: 0.0666 Time: 32.77s
# Epoch 83/100 Batch 512/641 Loss: 0.0664 Time: 32.80s
# Epoch 83/100 Batch 576/641 Loss: 0.0665 Time: 32.80s
# Epoch 83/100 Batch 640/641 Loss: 0.0665 Time: 32.79s
# Training 83/99 - Loss: 0.0665 - Time: 377.54s
# Tue Apr  8 20:39:45 2025 Epoch 84/99
# Epoch 84/100 Batch 0/641 Loss: 0.0872 Time: 48.88s
# Epoch 84/100 Batch 64/641 Loss: 0.0655 Time: 32.62s
# Epoch 84/100 Batch 128/641 Loss: 0.0666 Time: 32.69s
# Epoch 84/100 Batch 192/641 Loss: 0.0660 Time: 32.78s
# Epoch 84/100 Batch 256/641 Loss: 0.0661 Time: 32.78s
# Epoch 84/100 Batch 320/641 Loss: 0.0663 Time: 32.79s
# Epoch 84/100 Batch 384/641 Loss: 0.0661 Time: 32.78s
# Epoch 84/100 Batch 448/641 Loss: 0.0658 Time: 32.80s
# Epoch 84/100 Batch 512/641 Loss: 0.0661 Time: 32.81s
# Epoch 84/100 Batch 576/641 Loss: 0.0663 Time: 32.80s
# Epoch 84/100 Batch 640/641 Loss: 0.0663 Time: 32.80s
# Training 84/99 - Loss: 0.0663 - Time: 377.92s
# Validation 84/100 Batch 0/160 Dice_TC: 0.8816 Time: 9.05s
# Validation 84/100 Batch 16/160 Dice_TC: 0.9025 Time: 3.83s
# Validation 84/100 Batch 32/160 Dice_TC: 0.9048 Time: 4.12s
# Validation 84/100 Batch 48/160 Dice_TC: 0.9055 Time: 2.77s
# Validation 84/100 Batch 64/160 Dice_TC: 0.9031 Time: 3.47s
# Validation 84/100 Batch 80/160 Dice_TC: 0.9051 Time: 3.14s
# Validation 84/100 Batch 96/160 Dice_TC: 0.9049 Time: 3.10s
# Validation 84/100 Batch 112/160 Dice_TC: 0.9047 Time: 3.36s
# Validation 84/100 Batch 128/160 Dice_TC: 0.9052 Time: 3.47s
# Validation 84/100 Batch 144/160 Dice_TC: 0.9041 Time: 3.20s
# Validation 84/99 - Avg Dice: 0.9040 - Time: 42.65s
# Tue Apr  8 20:46:45 2025 Epoch 85/99
# Epoch 85/100 Batch 0/641 Loss: 0.0954 Time: 49.00s
# Epoch 85/100 Batch 64/641 Loss: 0.0685 Time: 32.56s
# Epoch 85/100 Batch 128/641 Loss: 0.0672 Time: 32.65s
# Epoch 85/100 Batch 192/641 Loss: 0.0669 Time: 32.74s
# Epoch 85/100 Batch 256/641 Loss: 0.0669 Time: 32.75s
# Epoch 85/100 Batch 320/641 Loss: 0.0667 Time: 32.75s
# Epoch 85/100 Batch 384/641 Loss: 0.0661 Time: 32.75s
# Epoch 85/100 Batch 448/641 Loss: 0.0663 Time: 32.78s
# Epoch 85/100 Batch 512/641 Loss: 0.0665 Time: 32.75s
# Epoch 85/100 Batch 576/641 Loss: 0.0664 Time: 32.77s
# Epoch 85/100 Batch 640/641 Loss: 0.0663 Time: 32.77s
# Training 85/99 - Loss: 0.0663 - Time: 377.59s
# Tue Apr  8 20:53:03 2025 Epoch 86/99
# Epoch 86/100 Batch 0/641 Loss: 0.0665 Time: 49.07s
# Epoch 86/100 Batch 64/641 Loss: 0.0672 Time: 32.60s
# Epoch 86/100 Batch 128/641 Loss: 0.0676 Time: 32.65s
# Epoch 86/100 Batch 192/641 Loss: 0.0658 Time: 32.74s
# Epoch 86/100 Batch 256/641 Loss: 0.0659 Time: 32.79s
# Epoch 86/100 Batch 320/641 Loss: 0.0667 Time: 32.80s
# Epoch 86/100 Batch 384/641 Loss: 0.0669 Time: 32.81s
# Epoch 86/100 Batch 448/641 Loss: 0.0666 Time: 32.80s
# Epoch 86/100 Batch 512/641 Loss: 0.0664 Time: 32.81s
# Epoch 86/100 Batch 576/641 Loss: 0.0662 Time: 32.79s
# Epoch 86/100 Batch 640/641 Loss: 0.0663 Time: 32.81s
# Training 86/99 - Loss: 0.0663 - Time: 378.02s
# Tue Apr  8 20:59:21 2025 Epoch 87/99
# Epoch 87/100 Batch 0/641 Loss: 0.0761 Time: 48.32s
# Epoch 87/100 Batch 64/641 Loss: 0.0662 Time: 32.59s
# Epoch 87/100 Batch 128/641 Loss: 0.0650 Time: 32.69s
# Epoch 87/100 Batch 192/641 Loss: 0.0657 Time: 32.72s
# Epoch 87/100 Batch 256/641 Loss: 0.0659 Time: 32.71s
# Epoch 87/100 Batch 320/641 Loss: 0.0656 Time: 32.78s
# Epoch 87/100 Batch 384/641 Loss: 0.0657 Time: 32.83s
# Epoch 87/100 Batch 448/641 Loss: 0.0659 Time: 32.83s
# Epoch 87/100 Batch 512/641 Loss: 0.0659 Time: 32.84s
# Epoch 87/100 Batch 576/641 Loss: 0.0659 Time: 32.83s
# Epoch 87/100 Batch 640/641 Loss: 0.0661 Time: 32.84s
# Training 87/99 - Loss: 0.0661 - Time: 377.33s
# Tue Apr  8 21:05:38 2025 Epoch 88/99
# Epoch 88/100 Batch 0/641 Loss: 0.0691 Time: 49.08s
# Epoch 88/100 Batch 64/641 Loss: 0.0660 Time: 32.59s
# Epoch 88/100 Batch 128/641 Loss: 0.0663 Time: 32.64s
# Epoch 88/100 Batch 192/641 Loss: 0.0662 Time: 32.73s
# Epoch 88/100 Batch 256/641 Loss: 0.0660 Time: 32.79s
# Epoch 88/100 Batch 320/641 Loss: 0.0662 Time: 32.80s
# Epoch 88/100 Batch 384/641 Loss: 0.0661 Time: 32.78s
# Epoch 88/100 Batch 448/641 Loss: 0.0661 Time: 32.80s
# Epoch 88/100 Batch 512/641 Loss: 0.0661 Time: 32.81s
# Epoch 88/100 Batch 576/641 Loss: 0.0661 Time: 32.79s
# Epoch 88/100 Batch 640/641 Loss: 0.0661 Time: 32.80s
# Training 88/99 - Loss: 0.0661 - Time: 377.96s
# Tue Apr  8 21:11:56 2025 Epoch 89/99
# Epoch 89/100 Batch 0/641 Loss: 0.0577 Time: 49.18s
# Epoch 89/100 Batch 64/641 Loss: 0.0657 Time: 32.60s
# Epoch 89/100 Batch 128/641 Loss: 0.0663 Time: 32.69s
# Epoch 89/100 Batch 192/641 Loss: 0.0658 Time: 32.70s
# Epoch 89/100 Batch 256/641 Loss: 0.0654 Time: 32.74s
# Epoch 89/100 Batch 320/641 Loss: 0.0655 Time: 32.81s
# Epoch 89/100 Batch 384/641 Loss: 0.0656 Time: 32.82s
# Epoch 89/100 Batch 448/641 Loss: 0.0657 Time: 32.81s
# Epoch 89/100 Batch 512/641 Loss: 0.0654 Time: 32.83s
# Epoch 89/100 Batch 576/641 Loss: 0.0658 Time: 32.81s
# Epoch 89/100 Batch 640/641 Loss: 0.0660 Time: 32.83s
# Training 89/99 - Loss: 0.0660 - Time: 378.16s
# Validation 89/100 Batch 0/160 Dice_TC: 0.8820 Time: 9.52s
# Validation 89/100 Batch 16/160 Dice_TC: 0.9027 Time: 3.55s
# Validation 89/100 Batch 32/160 Dice_TC: 0.9049 Time: 4.03s
# Validation 89/100 Batch 48/160 Dice_TC: 0.9057 Time: 2.55s
# Validation 89/100 Batch 64/160 Dice_TC: 0.9030 Time: 3.99s
# Validation 89/100 Batch 80/160 Dice_TC: 0.9050 Time: 3.07s
# Validation 89/100 Batch 96/160 Dice_TC: 0.9046 Time: 3.04s
# Validation 89/100 Batch 112/160 Dice_TC: 0.9045 Time: 3.41s
# Validation 89/100 Batch 128/160 Dice_TC: 0.9050 Time: 3.73s
# Validation 89/100 Batch 144/160 Dice_TC: 0.9039 Time: 2.92s
# Validation 89/99 - Avg Dice: 0.9038 - Time: 42.95s
# Tue Apr  8 21:18:57 2025 Epoch 90/99
# Epoch 90/100 Batch 0/641 Loss: 0.0569 Time: 49.14s
# Epoch 90/100 Batch 64/641 Loss: 0.0655 Time: 32.57s
# Epoch 90/100 Batch 128/641 Loss: 0.0663 Time: 32.66s
# Epoch 90/100 Batch 192/641 Loss: 0.0661 Time: 32.71s
# Epoch 90/100 Batch 256/641 Loss: 0.0658 Time: 32.73s
# Epoch 90/100 Batch 320/641 Loss: 0.0658 Time: 32.74s
# Epoch 90/100 Batch 384/641 Loss: 0.0655 Time: 32.74s
# Epoch 90/100 Batch 448/641 Loss: 0.0656 Time: 32.74s
# Epoch 90/100 Batch 512/641 Loss: 0.0657 Time: 32.74s
# Epoch 90/100 Batch 576/641 Loss: 0.0658 Time: 32.76s
# Epoch 90/100 Batch 640/641 Loss: 0.0659 Time: 32.74s
# Training 90/99 - Loss: 0.0659 - Time: 377.63s
# Tue Apr  8 21:25:15 2025 Epoch 91/99
# Epoch 91/100 Batch 0/641 Loss: 0.0639 Time: 48.60s
# Epoch 91/100 Batch 64/641 Loss: 0.0660 Time: 32.58s
# Epoch 91/100 Batch 128/641 Loss: 0.0655 Time: 32.65s
# Epoch 91/100 Batch 192/641 Loss: 0.0658 Time: 32.73s
# Epoch 91/100 Batch 256/641 Loss: 0.0659 Time: 32.79s
# Epoch 91/100 Batch 320/641 Loss: 0.0656 Time: 32.80s
# Epoch 91/100 Batch 384/641 Loss: 0.0656 Time: 32.80s
# Epoch 91/100 Batch 448/641 Loss: 0.0658 Time: 32.81s
# Epoch 91/100 Batch 512/641 Loss: 0.0658 Time: 32.82s
# Epoch 91/100 Batch 576/641 Loss: 0.0658 Time: 32.81s
# Epoch 91/100 Batch 640/641 Loss: 0.0658 Time: 32.79s
# Training 91/99 - Loss: 0.0658 - Time: 377.53s
# Tue Apr  8 21:31:33 2025 Epoch 92/99
# Epoch 92/100 Batch 0/641 Loss: 0.0565 Time: 48.93s
# Epoch 92/100 Batch 64/641 Loss: 0.0633 Time: 32.60s
# Epoch 92/100 Batch 128/641 Loss: 0.0649 Time: 32.69s
# Epoch 92/100 Batch 192/641 Loss: 0.0659 Time: 32.73s
# Epoch 92/100 Batch 256/641 Loss: 0.0656 Time: 32.74s
# Epoch 92/100 Batch 320/641 Loss: 0.0654 Time: 32.73s
# Epoch 92/100 Batch 384/641 Loss: 0.0655 Time: 32.74s
# Epoch 92/100 Batch 448/641 Loss: 0.0656 Time: 32.74s
# Epoch 92/100 Batch 512/641 Loss: 0.0660 Time: 32.75s
# Epoch 92/100 Batch 576/641 Loss: 0.0657 Time: 32.74s
# Epoch 92/100 Batch 640/641 Loss: 0.0658 Time: 32.74s
# Training 92/99 - Loss: 0.0658 - Time: 377.43s
# Tue Apr  8 21:37:50 2025 Epoch 93/99
# Epoch 93/100 Batch 0/641 Loss: 0.0845 Time: 48.97s
# Epoch 93/100 Batch 64/641 Loss: 0.0653 Time: 32.59s
# Epoch 93/100 Batch 128/641 Loss: 0.0660 Time: 32.70s
# Epoch 93/100 Batch 192/641 Loss: 0.0659 Time: 32.74s
# Epoch 93/100 Batch 256/641 Loss: 0.0661 Time: 32.75s
# Epoch 93/100 Batch 320/641 Loss: 0.0659 Time: 32.74s
# Epoch 93/100 Batch 384/641 Loss: 0.0660 Time: 32.75s
# Epoch 93/100 Batch 448/641 Loss: 0.0657 Time: 32.74s
# Epoch 93/100 Batch 512/641 Loss: 0.0657 Time: 32.75s
# Epoch 93/100 Batch 576/641 Loss: 0.0655 Time: 32.75s
# Epoch 93/100 Batch 640/641 Loss: 0.0657 Time: 32.74s
# Training 93/99 - Loss: 0.0657 - Time: 377.58s
# Tue Apr  8 21:44:08 2025 Epoch 94/99
# Epoch 94/100 Batch 0/641 Loss: 0.0751 Time: 48.28s
# Epoch 94/100 Batch 64/641 Loss: 0.0654 Time: 32.72s
# Epoch 94/100 Batch 128/641 Loss: 0.0658 Time: 32.65s
# Epoch 94/100 Batch 192/641 Loss: 0.0657 Time: 32.79s
# Epoch 94/100 Batch 256/641 Loss: 0.0660 Time: 32.79s
# Epoch 94/100 Batch 320/641 Loss: 0.0656 Time: 32.79s
# Epoch 94/100 Batch 384/641 Loss: 0.0656 Time: 32.79s
# Epoch 94/100 Batch 448/641 Loss: 0.0656 Time: 32.80s
# Epoch 94/100 Batch 512/641 Loss: 0.0656 Time: 32.79s
# Epoch 94/100 Batch 576/641 Loss: 0.0656 Time: 32.79s
# Epoch 94/100 Batch 640/641 Loss: 0.0657 Time: 32.79s
# Training 94/99 - Loss: 0.0657 - Time: 377.30s
# Validation 94/100 Batch 0/160 Dice_TC: 0.8817 Time: 9.46s
# Validation 94/100 Batch 16/160 Dice_TC: 0.9030 Time: 3.40s
# Validation 94/100 Batch 32/160 Dice_TC: 0.9053 Time: 4.16s
# Validation 94/100 Batch 48/160 Dice_TC: 0.9061 Time: 2.66s
# Validation 94/100 Batch 64/160 Dice_TC: 0.9036 Time: 3.73s
# Validation 94/100 Batch 80/160 Dice_TC: 0.9055 Time: 3.11s
# Validation 94/100 Batch 96/160 Dice_TC: 0.9052 Time: 3.07s
# Validation 94/100 Batch 112/160 Dice_TC: 0.9050 Time: 3.24s
# Validation 94/100 Batch 128/160 Dice_TC: 0.9055 Time: 3.56s
# Validation 94/100 Batch 144/160 Dice_TC: 0.9043 Time: 3.16s
# Validation 94/99 - Avg Dice: 0.9042 - Time: 42.64s
# Tue Apr  8 21:51:07 2025 Epoch 95/99
# Epoch 95/100 Batch 0/641 Loss: 0.0735 Time: 48.61s
# Epoch 95/100 Batch 64/641 Loss: 0.0676 Time: 32.73s
# Epoch 95/100 Batch 128/641 Loss: 0.0669 Time: 32.68s
# Epoch 95/100 Batch 192/641 Loss: 0.0667 Time: 32.72s
# Epoch 95/100 Batch 256/641 Loss: 0.0666 Time: 32.73s
# Epoch 95/100 Batch 320/641 Loss: 0.0663 Time: 32.72s
# Epoch 95/100 Batch 384/641 Loss: 0.0661 Time: 32.74s
# Epoch 95/100 Batch 448/641 Loss: 0.0663 Time: 32.73s
# Epoch 95/100 Batch 512/641 Loss: 0.0663 Time: 32.76s
# Epoch 95/100 Batch 576/641 Loss: 0.0661 Time: 32.74s
# Epoch 95/100 Batch 640/641 Loss: 0.0658 Time: 32.73s
# Training 95/99 - Loss: 0.0658 - Time: 377.19s
# Tue Apr  8 21:57:25 2025 Epoch 96/99
# Epoch 96/100 Batch 0/641 Loss: 0.0691 Time: 49.10s
# Epoch 96/100 Batch 64/641 Loss: 0.0638 Time: 32.60s
# Epoch 96/100 Batch 128/641 Loss: 0.0663 Time: 32.67s
# Epoch 96/100 Batch 192/641 Loss: 0.0655 Time: 32.77s
# Epoch 96/100 Batch 256/641 Loss: 0.0655 Time: 32.77s
# Epoch 96/100 Batch 320/641 Loss: 0.0658 Time: 32.78s
# Epoch 96/100 Batch 384/641 Loss: 0.0660 Time: 32.80s
# Epoch 96/100 Batch 448/641 Loss: 0.0660 Time: 32.79s
# Epoch 96/100 Batch 512/641 Loss: 0.0658 Time: 32.79s
# Epoch 96/100 Batch 576/641 Loss: 0.0655 Time: 32.79s
# Epoch 96/100 Batch 640/641 Loss: 0.0657 Time: 32.79s
# Training 96/99 - Loss: 0.0657 - Time: 377.98s
# Tue Apr  8 22:03:43 2025 Epoch 97/99
# Epoch 97/100 Batch 0/641 Loss: 0.0742 Time: 49.39s
# Epoch 97/100 Batch 64/641 Loss: 0.0654 Time: 32.58s
# Epoch 97/100 Batch 128/641 Loss: 0.0660 Time: 32.64s
# Epoch 97/100 Batch 192/641 Loss: 0.0664 Time: 32.73s
# Epoch 97/100 Batch 256/641 Loss: 0.0666 Time: 32.79s
# Epoch 97/100 Batch 320/641 Loss: 0.0662 Time: 32.78s
# Epoch 97/100 Batch 384/641 Loss: 0.0660 Time: 32.79s
# Epoch 97/100 Batch 448/641 Loss: 0.0660 Time: 32.81s
# Epoch 97/100 Batch 512/641 Loss: 0.0658 Time: 32.81s
# Epoch 97/100 Batch 576/641 Loss: 0.0658 Time: 32.81s
# Epoch 97/100 Batch 640/641 Loss: 0.0657 Time: 32.78s
# Training 97/99 - Loss: 0.0657 - Time: 378.27s
# Tue Apr  8 22:10:01 2025 Epoch 98/99
# Epoch 98/100 Batch 0/641 Loss: 0.0565 Time: 49.39s
# Epoch 98/100 Batch 64/641 Loss: 0.0659 Time: 32.57s
# Epoch 98/100 Batch 128/641 Loss: 0.0662 Time: 32.65s
# Epoch 98/100 Batch 192/641 Loss: 0.0658 Time: 32.66s
# Epoch 98/100 Batch 256/641 Loss: 0.0657 Time: 32.80s
# Epoch 98/100 Batch 320/641 Loss: 0.0657 Time: 32.81s
# Epoch 98/100 Batch 384/641 Loss: 0.0657 Time: 32.80s
# Epoch 98/100 Batch 448/641 Loss: 0.0661 Time: 32.82s
# Epoch 98/100 Batch 512/641 Loss: 0.0657 Time: 32.82s
# Epoch 98/100 Batch 576/641 Loss: 0.0658 Time: 32.79s
# Epoch 98/100 Batch 640/641 Loss: 0.0656 Time: 32.82s
# Training 98/99 - Loss: 0.0656 - Time: 378.29s
# Tue Apr  8 22:16:19 2025 Epoch 99/99
# Epoch 99/100 Batch 0/641 Loss: 0.0553 Time: 49.16s
# Epoch 99/100 Batch 64/641 Loss: 0.0636 Time: 32.56s
# Epoch 99/100 Batch 128/641 Loss: 0.0659 Time: 32.68s
# Epoch 99/100 Batch 192/641 Loss: 0.0664 Time: 32.70s
# Epoch 99/100 Batch 256/641 Loss: 0.0664 Time: 32.77s
# Epoch 99/100 Batch 320/641 Loss: 0.0666 Time: 32.81s
# Epoch 99/100 Batch 384/641 Loss: 0.0659 Time: 32.82s
# Epoch 99/100 Batch 448/641 Loss: 0.0659 Time: 32.82s
# Epoch 99/100 Batch 512/641 Loss: 0.0658 Time: 32.84s
# Epoch 99/100 Batch 576/641 Loss: 0.0658 Time: 32.82s
# Epoch 99/100 Batch 640/641 Loss: 0.0657 Time: 32.82s
# Training 99/99 - Loss: 0.0657 - Time: 378.14s
# Validation 99/100 Batch 0/160 Dice_TC: 0.8819 Time: 9.54s
# Validation 99/100 Batch 16/160 Dice_TC: 0.9030 Time: 3.30s
# Validation 99/100 Batch 32/160 Dice_TC: 0.9053 Time: 4.04s
# Validation 99/100 Batch 48/160 Dice_TC: 0.9061 Time: 3.02s
# Validation 99/100 Batch 64/160 Dice_TC: 0.9036 Time: 3.46s
# Validation 99/100 Batch 80/160 Dice_TC: 0.9055 Time: 3.22s
# Validation 99/100 Batch 96/160 Dice_TC: 0.9051 Time: 3.01s
# Validation 99/100 Batch 112/160 Dice_TC: 0.9050 Time: 3.22s
# Validation 99/100 Batch 128/160 Dice_TC: 0.9055 Time: 3.55s
# Validation 99/100 Batch 144/160 Dice_TC: 0.9043 Time: 3.17s
# Validation 99/99 - Avg Dice: 0.9042 - Time: 42.68s
# Training Complete! Best Validation Dice Score: 0.9056

# %%
# Ensure trains_epoch and loss_epochs match
assert len(trains_epoch) == len(loss_epochs), "Mismatch between epochs and loss values"

# Generate x-axis values for validation Dice
epochs = list(range(1, len(dices_avg) + 1))

# Create figure with a wider layout
plt.figure("Training and Validation Metrics", figsize=(14, 6), dpi=100)

# --- Subplot 1: Training Loss ---
plt.subplot(1, 2, 1)
plt.plot(trains_epoch, loss_epochs, color="#E74C3C", linestyle="--", marker="o", markersize=6, label="Train Loss")
plt.title("Epoch Average Loss", fontsize=16, fontweight="bold", color="#2C3E50")
plt.xlabel("Epoch", fontsize=12, fontweight="bold", color="#34495E")
plt.ylabel("Loss", fontsize=12, fontweight="bold", color="#34495E")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(fontsize=12, loc="upper right")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Subplot 2: Validation Mean Dice ---
plt.subplot(1, 2, 2)
plt.plot(epochs, dices_avg, color="#27AE60", linestyle="--", marker="o", markersize=6, label="Val Mean Dice")
plt.title("Validation Mean Dice", fontsize=16, fontweight="bold", color="#2C3E50")
plt.xlabel("Epoch", fontsize=12, fontweight="bold", color="#34495E")
plt.ylabel("Dice Score", fontsize=12, fontweight="bold", color="#34495E")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(fontsize=12, loc="lower right")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Adjust layout and show the final result
plt.tight_layout()
plt.show()

# %%
# Run from Lab's PC.
#model_path = "C:\\Users\\manto\OneDrive\\Desktop\\Ilektra_Thesis_Code_Final\\Coronary-Arteries-Segmentation-with-BasicUNet\\LimitedData"

# Run from my laptop
model_path = "D:\\Coronary-Arteries-Segmentation-with-BasicUNet\\OriginalDataset_Experiment2"

model.load_state_dict(torch.load(os.path.join(model_path, "best_model.pth")))
model.to(device)
model.eval()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18436\3368374333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(os.path.join(model_path, "best_model.pth")))
# BasicUNet(
#   (conv_0): TwoConv(
#     (conv_0): Convolution(
#       (conv): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (adn): ADN(
#         (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (D): Dropout(p=0.1, inplace=False)
#         (A): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (conv_1): Convolution(
#       (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (adn): ADN(
#         (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (D): Dropout(p=0.1, inplace=False)
#         (A): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#   )
#   (down_1): Down(
#     (max_pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (down_2): Down(
#     (max_pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (down_3): Down(
#     (max_pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (down_4): Down(
#     (max_pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (upcat_4): UpCat(
#     (upsample): UpSample(
#       (deconv): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#     )
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (upcat_3): UpCat(
#     (upsample): UpSample(
#       (deconv): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#     )
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (upcat_2): UpCat(
#     (upsample): UpSample(
#       (deconv): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#     )
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (upcat_1): UpCat(
#     (upsample): UpSample(
#       (deconv): ConvTranspose3d(32, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#     )
#     (convs): TwoConv(
#       (conv_0): Convolution(
#         (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (conv_1): Convolution(
#         (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (adn): ADN(
#           (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (D): Dropout(p=0.1, inplace=False)
#           (A): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (final_conv): Conv3d(32, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
# Post-processing transforms for prediction
post_sigmoid = Activations(sigmoid=True)
post_pred = AsDiscrete(argmax=False, threshold=0.5)

# %%
import os
import glob

# test images
test_images = sorted(glob.glob(os.path.join(data_dir, 'Cropped_TestData', '*.img.nii.gz')))
test_labels = sorted(glob.glob(os.path.join(data_dir, 'Cropped_TestData', '*.label.nii.gz')))

# Create dictionaries with a path of each image and each label just like train and validation
test_files = [{"image": image_name, "label": label_name} for image_name, label_name in zip(test_images, test_labels)]


# Define appropriate transforms for your task
test_transform = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image", "label"]),
        transforms.EnsureChannelFirstd(keys=["image", "label"]),
        transforms.ScaleIntensityRanged(
            keys=["image"],
            a_min=-1024,
            a_max=1500,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        #transforms.Spacingd(
        #    keys=["image", "label"],
        #    pixdim=(0.38, 0.38, 0.5), 
        #    mode=("bilinear", "nearest")
        #),
        transforms.Resized(keys=["image", "label"], spatial_size=(roi[0], roi[1], roi[2]), mode=['area', 'nearest']),
        transforms.ToTensorD(keys=["image", "label"]),
    ]
)

# Create dataset and loader
test_ds = data.Dataset(data=test_files, transform=test_transform)
test_loader = data.DataLoader(
    test_ds,
    batch_size=1,  # Adjust based on GPU capacity
    shuffle=False,
    num_workers=1,
    pin_memory=True,
)

# Post-processing functions for binary segmentation
post_sigmoid = torch.sigmoid
# Thresholding at 0.5 for binary
post_pred = lambda x: (x > 0.5).float()

# %%
import os
import torch
import nibabel as nib
import matplotlib.pyplot as plt
from monai.inferers import sliding_window_inference
import numpy as np

# Saves them in LPI transform while original images are RPI. 
# Kept only for comparisons. This is why I needed to change the approach. 

# Slice map for specific slices
slice_map = {
    "cropped_901.img.nii.gz": 80,
    "cropped_902.img.nii.gz": 81,
    "cropped_903.img.nii.gz": 82,
    "cropped_904.img.nii.gz": 83,
    "cropped_905.img.nii.gz": 84,
    "cropped_906.img.nii.gz": 85,
}

# Specify the case number and the output directory
case_num = 21
output_dir = "D:\\Electra\\data\\Results\\BasicUNet\\Original\\LPI_Oriented"
os.makedirs(output_dir, exist_ok=True)

with torch.no_grad():
    # Load image and label from test dataset
    img = test_ds[case_num]["image"]
    label = test_ds[case_num]["label"]

    # Get the original filename from metadata
    img_name = os.path.basename(img.meta["filename_or_obj"])
    print(f"Processing image: {img_name}")

    # Add batch and channel dimensions, move to GPU
    test_inputs = torch.unsqueeze(img, 1).cuda()
    test_labels = torch.unsqueeze(label, 1).cuda()

    # Perform inference
    test_outputs = sliding_window_inference(test_inputs, (128, 128, 128), 4, model, overlap=0.5)

    # Choose slice to visualize
    slice_idx = slice_map.get(img_name, test_inputs.shape[-1] // 2)

    # Visualize image, label, and prediction
    plt.figure("check", (18, 6))
    plt.subplot(1, 3, 1)
    plt.title("Image")
    plt.imshow(test_inputs.cpu().numpy()[0, 0, :, :, slice_idx], cmap="gray")

    plt.subplot(1, 3, 2)
    plt.title("Label")
    plt.imshow(test_labels.cpu().numpy()[0, 0, :, :, slice_idx])

    plt.subplot(1, 3, 3)
    plt.title("Output")
    plt.imshow(torch.argmax(test_outputs, dim=1).detach().cpu()[0, :, :, slice_idx])

    plt.show()

    # Define output file paths
    img_save_path = os.path.join(output_dir, f"testimage_case_{case_num}.nii.gz")
    label_save_path = os.path.join(output_dir, f"testlabel_case_{case_num}.nii.gz")
    output_save_path = os.path.join(output_dir, f"testoutput_case_{case_num}.nii.gz")

    # Save image, label, and prediction as NIfTI
    nib.save(nib.Nifti1Image(test_inputs.cpu().numpy()[0, 0], affine=np.eye(4)), img_save_path)
    nib.save(nib.Nifti1Image(test_labels.cpu().numpy()[0, 0], affine=np.eye(4)), label_save_path)

    prediction = torch.argmax(test_outputs, dim=1).detach().cpu().numpy()[0].astype(np.int32)
    nib.save(nib.Nifti1Image(prediction, affine=np.eye(4)), output_save_path)

    print(f"Saved image to: {img_save_path}")
    print(f"Saved label to: {label_save_path}")
    print(f"Saved output to: {output_save_path}")
# Out:
# Processing image: cropped_839.img.nii.gz
# Saved image to: D:\Electra\data\Results\BasicUNet\Original\LPI_Oriented\testimage_case_21.nii.gz
# Saved label to: D:\Electra\data\Results\BasicUNet\Original\LPI_Oriented\testlabel_case_21.nii.gz
# Saved output to: D:\Electra\data\Results\BasicUNet\Original\LPI_Oriented\testoutput_case_21.nii.gz

# %%
import os
import torch
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from monai.inferers import sliding_window_inference
from monai.transforms import SaveImaged

# Output directory
output_dir = "D:\\Electra\\data\\Results\\BasicUNet\\Original"
os.makedirs(output_dir, exist_ok=True)

# Choose test case index
case_index = 3
model.eval()

with torch.no_grad():
    sample = test_ds[case_index]
    image = sample["image"]
    label = sample["label"]
    image_name = os.path.basename(image.meta["filename_or_obj"])
    print(f"Processing image: {image_name}")

    # Add batch + channel and move to GPU
    test_input = torch.unsqueeze(image, 1).cuda()

    # Predict
    raw_pred = sliding_window_inference(test_input, (128, 128, 128), 4, model, overlap=0.5)
    print("Prediction shape:", raw_pred.shape)

    # Use argmax to get predicted class
    pred_class = torch.argmax(raw_pred, dim=1)  # shape: [1, H, W, D]

    # Extract only class 1 (artery mask), convert to binary mask
    artery_mask = (pred_class == 1).to(torch.uint8)

    # Remove batch dimension
    artery_mask = artery_mask[0]

    # Attach metadata and affine for correct alignment
    artery_mask.meta = image.meta
    artery_mask.affine = image.affine
    label.affine = image.affine

    # Save everythinh
    saver_img  = SaveImaged(keys="image", output_dir=output_dir, output_postfix="test_basicunet_original", separate_folder=False, resample=False, print_log=True)
    saver_lbl  = SaveImaged(keys="label", output_dir=output_dir, output_postfix="test_basicunet_original", separate_folder=False, resample=False, print_log=True)
    saver_pred = SaveImaged(keys="prediction", output_dir=output_dir, output_postfix="prediction_basicunet_original", separate_folder=False, resample=False, print_log=True)

    saver_img({"image": image})
    saver_lbl({"label": label})
    saver_pred({"prediction": artery_mask})
# Out:
# Processing image: cropped_822.img.nii.gz
# Prediction shape: torch.Size([1, 2, 128, 128, 128])
# 2025-05-02 16:53:51,619 INFO image_writer.py:197 - writing: D:\Electra\data\Results\BasicUNet\Original\cropped_822.img_test_basicunet_original.nii.gz
# 2025-05-02 16:53:52,111 INFO image_writer.py:197 - writing: D:\Electra\data\Results\BasicUNet\Original\cropped_822.label_test_basicunet_original.nii.gz
# 2025-05-02 16:53:52,160 INFO image_writer.py:197 - writing: D:\Electra\data\Results\BasicUNet\Original\cropped_822.img_prediction_basicunet_original.nii.gz

# %%
import torch
from monai.metrics import DiceMetric
from monai.transforms import Compose, AsDiscrete
from monai.data import DataLoader, decollate_batch

# DiceMetric includes background class and computes mean across batch
dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=True)

# Separate post-processing for outputs and labels
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])  
post_label = Compose([AsDiscrete(to_onehot=2)])              

# Set model to evaluation mode
model.eval()

# Create test DataLoader
test_loader = DataLoader(test_ds, batch_size=1, num_workers=4)

with torch.no_grad():
    for batch in test_loader:
        images = batch["image"].to(device)
        labels = batch["label"].to(device)

        # Forward pass
        outputs = model(images)

        # Decollate and apply post-processing
        outputs = [post_pred(i.cpu()) for i in decollate_batch(outputs)]
        labels = [post_label(i.cpu()) for i in decollate_batch(labels)]

        # Compute Dice
        dice_metric(y_pred=outputs, y=labels)

# Aggregate Dice and reset metric
mean_dice, _ = dice_metric.aggregate()
dice_metric.reset()

print(f"Test Dice Score (with background): {mean_dice.item():.4f}")
# Out:
# Test Dice Score (with background): 0.9096

# %%
import torch
from monai.metrics import DiceMetric
from monai.transforms import Compose, AsDiscrete
from monai.data import DataLoader, decollate_batch

# DiceMetric for single-sample evaluation (mean over classes)
dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=True)

# Post-processing transforms
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])  
post_label = Compose([AsDiscrete(to_onehot=2)])              

# Model to eval mode
model.eval()

# Test DataLoader
test_loader = DataLoader(test_ds, batch_size=1, num_workers=4)

# Store per-sample Dice scores
sample_dice_scores = []

with torch.no_grad():
    for i, batch in enumerate(test_loader):
        images = batch["image"].to(device)
        labels = batch["label"].to(device)

        # Forward pass
        outputs = model(images)

        # Decollate and post-process
        outputs = [post_pred(o.cpu()) for o in decollate_batch(outputs)]
        labels = [post_label(l.cpu()) for l in decollate_batch(labels)]

        # Compute Dice
        dice_metric(y_pred=outputs, y=labels)
        sample_dice, _ = dice_metric.aggregate()
        dice_metric.reset()

        # Store and print
        score = sample_dice.item()
        sample_dice_scores.append(score)
        print(f"Sample {i:03d} Dice Score: {score:.4f}")

# Compute final average
final_avg_dice = sum(sample_dice_scores) / len(sample_dice_scores)
print(f"\nFinal Average Dice Score: {final_avg_dice:.4f}")
# Out:
# Sample 000 Dice Score: 0.9313
# Sample 001 Dice Score: 0.9218
# Sample 002 Dice Score: 0.9304
# Sample 003 Dice Score: 0.9253
# Sample 004 Dice Score: 0.9148
# Sample 005 Dice Score: 0.9316
# Sample 006 Dice Score: 0.9400
# Sample 007 Dice Score: 0.8933
# Sample 008 Dice Score: 0.8969
# Sample 009 Dice Score: 0.9034
# Sample 010 Dice Score: 0.9194
# Sample 011 Dice Score: 0.8899
# Sample 012 Dice Score: 0.9387
# Sample 013 Dice Score: 0.9402
# Sample 014 Dice Score: 0.9325
# Sample 015 Dice Score: 0.9372
# Sample 016 Dice Score: 0.9135
# Sample 017 Dice Score: 0.9139
# Sample 018 Dice Score: 0.9222
# Sample 019 Dice Score: 0.9190
# Sample 020 Dice Score: 0.8907
# Sample 021 Dice Score: 0.9283
# Sample 022 Dice Score: 0.9302
# Sample 023 Dice Score: 0.9048
# Sample 024 Dice Score: 0.9147
# Sample 025 Dice Score: 0.8810
# Sample 026 Dice Score: 0.8964
# Sample 027 Dice Score: 0.9243
# Sample 028 Dice Score: 0.8995
# Sample 029 Dice Score: 0.9168
# Sample 030 Dice Score: 0.9259
# Sample 031 Dice Score: 0.8965
# Sample 032 Dice Score: 0.9012
# Sample 033 Dice Score: 0.8662
# Sample 034 Dice Score: 0.8578
# Sample 035 Dice Score: 0.9297
# Sample 036 Dice Score: 0.9092
# Sample 037 Dice Score: 0.9451
# Sample 038 Dice Score: 0.8736
# Sample 039 Dice Score: 0.9080
# Sample 040 Dice Score: 0.9228
# Sample 041 Dice Score: 0.9050
# Sample 042 Dice Score: 0.8749
# Sample 043 Dice Score: 0.9280
# Sample 044 Dice Score: 0.8395
# Sample 045 Dice Score: 0.9085
# Sample 046 Dice Score: 0.8860
# Sample 047 Dice Score: 0.8958
# Sample 048 Dice Score: 0.9172
# Sample 049 Dice Score: 0.9158
# Sample 050 Dice Score: 0.8902
# Sample 051 Dice Score: 0.9328
# Sample 052 Dice Score: 0.8715
# Sample 053 Dice Score: 0.8992
# Sample 054 Dice Score: 0.8502
# Sample 055 Dice Score: 0.9163
# Sample 056 Dice Score: 0.8905
# Sample 057 Dice Score: 0.9091
# Sample 058 Dice Score: 0.9125
# Sample 059 Dice Score: 0.9393
# Sample 060 Dice Score: 0.8968
# Sample 061 Dice Score: 0.9088
# Sample 062 Dice Score: 0.8914
# Sample 063 Dice Score: 0.9081
# Sample 064 Dice Score: 0.8985
# Sample 065 Dice Score: 0.9424
# Sample 066 Dice Score: 0.9224
# Sample 067 Dice Score: 0.9030
# Sample 068 Dice Score: 0.9098
# Sample 069 Dice Score: 0.9266
# Sample 070 Dice Score: 0.9165
# Sample 071 Dice Score: 0.9406
# Sample 072 Dice Score: 0.9021
# Sample 073 Dice Score: 0.8462
# Sample 074 Dice Score: 0.9019
# Sample 075 Dice Score: 0.9246
# Sample 076 Dice Score: 0.9228
# Sample 077 Dice Score: 0.9175
# Sample 078 Dice Score: 0.9392
# Sample 079 Dice Score: 0.9325
# Sample 080 Dice Score: 0.8900
# Sample 081 Dice Score: 0.9258
# Sample 082 Dice Score: 0.8695
# Sample 083 Dice Score: 0.8855
# Sample 084 Dice Score: 0.8863
# Sample 085 Dice Score: 0.9222
# Sample 086 Dice Score: 0.9338
# Sample 087 Dice Score: 0.9452
# Sample 088 Dice Score: 0.9090
# Sample 089 Dice Score: 0.9007
# Sample 090 Dice Score: 0.9339
# Sample 091 Dice Score: 0.8799
# Sample 092 Dice Score: 0.8794
# Sample 093 Dice Score: 0.9410
# Sample 094 Dice Score: 0.8575
# Sample 095 Dice Score: 0.8883
# Sample 096 Dice Score: 0.9241
# Sample 097 Dice Score: 0.8938
# Sample 098 Dice Score: 0.9120
# Sample 099 Dice Score: 0.8467
# Sample 100 Dice Score: 0.9272
# Sample 101 Dice Score: 0.8944
# Sample 102 Dice Score: 0.9315
# Sample 103 Dice Score: 0.9117
# Sample 104 Dice Score: 0.9101
# Sample 105 Dice Score: 0.9070
# Sample 106 Dice Score: 0.9332
# Sample 107 Dice Score: 0.9063
# Sample 108 Dice Score: 0.9171
# Sample 109 Dice Score: 0.9189
# Sample 110 Dice Score: 0.9342
# Sample 111 Dice Score: 0.9048
# Sample 112 Dice Score: 0.9240
# Sample 113 Dice Score: 0.9267
# Sample 114 Dice Score: 0.8894
# Sample 115 Dice Score: 0.9324
# Sample 116 Dice Score: 0.8852
# Sample 117 Dice Score: 0.9248
# Sample 118 Dice Score: 0.9172
# Sample 119 Dice Score: 0.8819
# Sample 120 Dice Score: 0.9082
# Sample 121 Dice Score: 0.9017
# Sample 122 Dice Score: 0.9034
# Sample 123 Dice Score: 0.9222
# Sample 124 Dice Score: 0.8797
# Sample 125 Dice Score: 0.9156
# Sample 126 Dice Score: 0.9286
# Sample 127 Dice Score: 0.9460
# Sample 128 Dice Score: 0.9484
# Sample 129 Dice Score: 0.9113
# Sample 130 Dice Score: 0.9061
# Sample 131 Dice Score: 0.9277
# Sample 132 Dice Score: 0.8772
# Sample 133 Dice Score: 0.9151
# Sample 134 Dice Score: 0.9129
# Sample 135 Dice Score: 0.9121
# Sample 136 Dice Score: 0.9051
# Sample 137 Dice Score: 0.9261
# Sample 138 Dice Score: 0.9278
# Sample 139 Dice Score: 0.9071
# Sample 140 Dice Score: 0.8511
# Sample 141 Dice Score: 0.8972
# Sample 142 Dice Score: 0.9429
# Sample 143 Dice Score: 0.9296
# Sample 144 Dice Score: 0.9435
# Sample 145 Dice Score: 0.9377
# Sample 146 Dice Score: 0.9091
# Sample 147 Dice Score: 0.9127
# Sample 148 Dice Score: 0.8900
# Sample 149 Dice Score: 0.9077
# Sample 150 Dice Score: 0.9053
# Sample 151 Dice Score: 0.9195
# Sample 152 Dice Score: 0.8973
# Sample 153 Dice Score: 0.8873
# Sample 154 Dice Score: 0.8963
# Sample 155 Dice Score: 0.8887
# Sample 156 Dice Score: 0.9347
# Sample 157 Dice Score: 0.9366
# Sample 158 Dice Score: 0.8869
# Sample 159 Dice Score: 0.9241
# Sample 160 Dice Score: 0.9305
# Sample 161 Dice Score: 0.9035
# Sample 162 Dice Score: 0.9084
# Sample 163 Dice Score: 0.9304
# Sample 164 Dice Score: 0.9211
# Sample 165 Dice Score: 0.9192
# Sample 166 Dice Score: 0.9011
# Sample 167 Dice Score: 0.8858
# Sample 168 Dice Score: 0.8525
# Sample 169 Dice Score: 0.8989
# Sample 170 Dice Score: 0.9259
# Sample 171 Dice Score: 0.9133
# Sample 172 Dice Score: 0.9192
# Sample 173 Dice Score: 0.8800
# Sample 174 Dice Score: 0.9172
# Sample 175 Dice Score: 0.8824
# Sample 176 Dice Score: 0.9296
# Sample 177 Dice Score: 0.8914
# Sample 178 Dice Score: 0.8968
# Sample 179 Dice Score: 0.9300
# Sample 180 Dice Score: 0.9356
# Sample 181 Dice Score: 0.8887
# Sample 182 Dice Score: 0.9372
# Sample 183 Dice Score: 0.9188
# Sample 184 Dice Score: 0.9064
# Sample 185 Dice Score: 0.8989
# Sample 186 Dice Score: 0.9087
# Sample 187 Dice Score: 0.9057
# Sample 188 Dice Score: 0.9123
# Sample 189 Dice Score: 0.9311
# Sample 190 Dice Score: 0.9292
# Sample 191 Dice Score: 0.9321
# Sample 192 Dice Score: 0.9140
# Sample 193 Dice Score: 0.9108
# Sample 194 Dice Score: 0.8751
# Sample 195 Dice Score: 0.9269
# Sample 196 Dice Score: 0.9071
# Sample 197 Dice Score: 0.9210
# Sample 198 Dice Score: 0.8508
#
# Final Average Dice Score: 0.9096

# %%
import torch
from monai.metrics import DiceMetric
from monai.transforms import Compose, AsDiscrete
from monai.data import DataLoader, decollate_batch

# DiceMetric for single-sample evaluation (mean over classes)
dice_metric = DiceMetric(include_background=False, reduction="mean", get_not_nans=True)

# Post-processing transforms
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])  
post_label = Compose([AsDiscrete(to_onehot=2)])              

# Model to eval mode
model.eval()

# Test DataLoader
test_loader = DataLoader(test_ds, batch_size=1, num_workers=4)

# Store per-sample Dice scores
sample_dice_scores = []

with torch.no_grad():
    for i, batch in enumerate(test_loader):
        images = batch["image"].to(device)
        labels = batch["label"].to(device)

        # Forward pass
        outputs = model(images)

        # Decollate and post-process
        outputs = [post_pred(o.cpu()) for o in decollate_batch(outputs)]
        labels = [post_label(l.cpu()) for l in decollate_batch(labels)]

        # Compute Dice
        dice_metric(y_pred=outputs, y=labels)
        sample_dice, _ = dice_metric.aggregate()
        dice_metric.reset()

        # Store and print
        score = sample_dice.item()
        sample_dice_scores.append(score)
        print(f"Sample {i:03d} Dice Score: {score:.4f}")

# Compute final average
final_avg_dice = sum(sample_dice_scores) / len(sample_dice_scores)
print(f"\nFinal Average Dice Score (foreground only): {final_avg_dice:.4f}")
# Out:
# Sample 000 Dice Score: 0.8636
# Sample 001 Dice Score: 0.8448
# Sample 002 Dice Score: 0.8616
# Sample 003 Dice Score: 0.8518
# Sample 004 Dice Score: 0.8308
# Sample 005 Dice Score: 0.8639
# Sample 006 Dice Score: 0.8809
# Sample 007 Dice Score: 0.7886
# Sample 008 Dice Score: 0.7949
# Sample 009 Dice Score: 0.8086
# Sample 010 Dice Score: 0.8401
# Sample 011 Dice Score: 0.7816
# Sample 012 Dice Score: 0.8780
# Sample 013 Dice Score: 0.8811
# Sample 014 Dice Score: 0.8660
# Sample 015 Dice Score: 0.8754
# Sample 016 Dice Score: 0.8284
# Sample 017 Dice Score: 0.8288
# Sample 018 Dice Score: 0.8454
# Sample 019 Dice Score: 0.8393
# Sample 020 Dice Score: 0.7832
# Sample 021 Dice Score: 0.8574
# Sample 022 Dice Score: 0.8611
# Sample 023 Dice Score: 0.8108
# Sample 024 Dice Score: 0.8305
# Sample 025 Dice Score: 0.7633
# Sample 026 Dice Score: 0.7943
# Sample 027 Dice Score: 0.8495
# Sample 028 Dice Score: 0.8000
# Sample 029 Dice Score: 0.8344
# Sample 030 Dice Score: 0.8524
# Sample 031 Dice Score: 0.7940
# Sample 032 Dice Score: 0.8041
# Sample 033 Dice Score: 0.7346
# Sample 034 Dice Score: 0.7171
# Sample 035 Dice Score: 0.8601
# Sample 036 Dice Score: 0.8199
# Sample 037 Dice Score: 0.8909
# Sample 038 Dice Score: 0.7487
# Sample 039 Dice Score: 0.8175
# Sample 040 Dice Score: 0.8468
# Sample 041 Dice Score: 0.8117
# Sample 042 Dice Score: 0.7514
# Sample 043 Dice Score: 0.8569
# Sample 044 Dice Score: 0.6812
# Sample 045 Dice Score: 0.8185
# Sample 046 Dice Score: 0.7732
# Sample 047 Dice Score: 0.7927
# Sample 048 Dice Score: 0.8354
# Sample 049 Dice Score: 0.8329
# Sample 050 Dice Score: 0.7813
# Sample 051 Dice Score: 0.8665
# Sample 052 Dice Score: 0.7459
# Sample 053 Dice Score: 0.7994
# Sample 054 Dice Score: 0.7030
# Sample 055 Dice Score: 0.8337
# Sample 056 Dice Score: 0.7826
# Sample 057 Dice Score: 0.8194
# Sample 058 Dice Score: 0.8261
# Sample 059 Dice Score: 0.8796
# Sample 060 Dice Score: 0.7950
# Sample 061 Dice Score: 0.8189
# Sample 062 Dice Score: 0.7842
# Sample 063 Dice Score: 0.8172
# Sample 064 Dice Score: 0.7985
# Sample 065 Dice Score: 0.8855
# Sample 066 Dice Score: 0.8457
# Sample 067 Dice Score: 0.8070
# Sample 068 Dice Score: 0.8206
# Sample 069 Dice Score: 0.8546
# Sample 070 Dice Score: 0.8338
# Sample 071 Dice Score: 0.8819
# Sample 072 Dice Score: 0.8053
# Sample 073 Dice Score: 0.6948
# Sample 074 Dice Score: 0.8054
# Sample 075 Dice Score: 0.8499
# Sample 076 Dice Score: 0.8465
# Sample 077 Dice Score: 0.8361
# Sample 078 Dice Score: 0.8791
# Sample 079 Dice Score: 0.8657
# Sample 080 Dice Score: 0.7818
# Sample 081 Dice Score: 0.8527
# Sample 082 Dice Score: 0.7409
# Sample 083 Dice Score: 0.7727
# Sample 084 Dice Score: 0.7737
# Sample 085 Dice Score: 0.8455
# Sample 086 Dice Score: 0.8687
# Sample 087 Dice Score: 0.8909
# Sample 088 Dice Score: 0.8194
# Sample 089 Dice Score: 0.8031
# Sample 090 Dice Score: 0.8686
# Sample 091 Dice Score: 0.7615
# Sample 092 Dice Score: 0.7609
# Sample 093 Dice Score: 0.8825
# Sample 094 Dice Score: 0.7177
# Sample 095 Dice Score: 0.7781
# Sample 096 Dice Score: 0.8494
# Sample 097 Dice Score: 0.7891
# Sample 098 Dice Score: 0.8250
# Sample 099 Dice Score: 0.6948
# Sample 100 Dice Score: 0.8556
# Sample 101 Dice Score: 0.7902
# Sample 102 Dice Score: 0.8637
# Sample 103 Dice Score: 0.8243
# Sample 104 Dice Score: 0.8214
# Sample 105 Dice Score: 0.8154
# Sample 106 Dice Score: 0.8674
# Sample 107 Dice Score: 0.8138
# Sample 108 Dice Score: 0.8352
# Sample 109 Dice Score: 0.8388
# Sample 110 Dice Score: 0.8693
# Sample 111 Dice Score: 0.8106
# Sample 112 Dice Score: 0.8488
# Sample 113 Dice Score: 0.8544
# Sample 114 Dice Score: 0.7800
# Sample 115 Dice Score: 0.8657
# Sample 116 Dice Score: 0.7719
# Sample 117 Dice Score: 0.8506
# Sample 118 Dice Score: 0.8353
# Sample 119 Dice Score: 0.7651
# Sample 120 Dice Score: 0.8172
# Sample 121 Dice Score: 0.8047
# Sample 122 Dice Score: 0.8083
# Sample 123 Dice Score: 0.8456
# Sample 124 Dice Score: 0.7606
# Sample 125 Dice Score: 0.8324
# Sample 126 Dice Score: 0.8581
# Sample 127 Dice Score: 0.8926
# Sample 128 Dice Score: 0.8973
# Sample 129 Dice Score: 0.8238
# Sample 130 Dice Score: 0.8134
# Sample 131 Dice Score: 0.8565
# Sample 132 Dice Score: 0.7557
# Sample 133 Dice Score: 0.8312
# Sample 134 Dice Score: 0.8267
# Sample 135 Dice Score: 0.8252
# Sample 136 Dice Score: 0.8115
# Sample 137 Dice Score: 0.8531
# Sample 138 Dice Score: 0.8565
# Sample 139 Dice Score: 0.8155
# Sample 140 Dice Score: 0.7041
# Sample 141 Dice Score: 0.7958
# Sample 142 Dice Score: 0.8867
# Sample 143 Dice Score: 0.8599
# Sample 144 Dice Score: 0.8876
# Sample 145 Dice Score: 0.8761
# Sample 146 Dice Score: 0.8198
# Sample 147 Dice Score: 0.8263
# Sample 148 Dice Score: 0.7819
# Sample 149 Dice Score: 0.8166
# Sample 150 Dice Score: 0.8120
# Sample 151 Dice Score: 0.8398
# Sample 152 Dice Score: 0.7963
# Sample 153 Dice Score: 0.7761
# Sample 154 Dice Score: 0.7938
# Sample 155 Dice Score: 0.7791
# Sample 156 Dice Score: 0.8702
# Sample 157 Dice Score: 0.8739
# Sample 158 Dice Score: 0.7757
# Sample 159 Dice Score: 0.8494
# Sample 160 Dice Score: 0.8619
# Sample 161 Dice Score: 0.8090
# Sample 162 Dice Score: 0.8179
# Sample 163 Dice Score: 0.8618
# Sample 164 Dice Score: 0.8431
# Sample 165 Dice Score: 0.8394
# Sample 166 Dice Score: 0.8030
# Sample 167 Dice Score: 0.7729
# Sample 168 Dice Score: 0.7072
# Sample 169 Dice Score: 0.7992
# Sample 170 Dice Score: 0.8532
# Sample 171 Dice Score: 0.8284
# Sample 172 Dice Score: 0.8399
# Sample 173 Dice Score: 0.7619
# Sample 174 Dice Score: 0.8355
# Sample 175 Dice Score: 0.7667
# Sample 176 Dice Score: 0.8599
# Sample 177 Dice Score: 0.7849
# Sample 178 Dice Score: 0.7953
# Sample 179 Dice Score: 0.8607
# Sample 180 Dice Score: 0.8718
# Sample 181 Dice Score: 0.7794
# Sample 182 Dice Score: 0.8752
# Sample 183 Dice Score: 0.8386
# Sample 184 Dice Score: 0.8142
# Sample 185 Dice Score: 0.7995
# Sample 186 Dice Score: 0.8186
# Sample 187 Dice Score: 0.8127
# Sample 188 Dice Score: 0.8257
# Sample 189 Dice Score: 0.8629
# Sample 190 Dice Score: 0.8594
# Sample 191 Dice Score: 0.8649
# Sample 192 Dice Score: 0.8296
# Sample 193 Dice Score: 0.8229
# Sample 194 Dice Score: 0.7519
# Sample 195 Dice Score: 0.8548
# Sample 196 Dice Score: 0.8157
# Sample 197 Dice Score: 0.8434
# Sample 198 Dice Score: 0.7037
#
# Final Average Dice Score (foreground only): 0.8204

# %%
import torch
import random
import numpy as np
import matplotlib.pyplot as plt

# Select a random sample from test_loader
random_index = random.randint(0, len(test_ds) - 1)  # Get a random index

# Load the sample
sample = test_ds[random_index]

# Extract image, ground truth, and model prediction
image = sample["image"].unsqueeze(0).to(device)  # Add batch dimension
label = sample["label"].cpu().numpy()[0, :, :, 64]  # Extract slice in z-direction

# Get model prediction
with torch.no_grad():
    pred = model(image)
    pred = post_pred(pred[0].cpu()).numpy()[0, :, :, 64]  # Extract slice

# Convert image for visualization
image = image.cpu().numpy()[0, 0, :, :, 100]  # Extract grayscale image slice

# Plot the image, ground truth, and prediction
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(image, cmap="gray")

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(label, cmap="jet", alpha=0.6)

plt.subplot(1, 3, 3)
plt.title("Model Prediction")
plt.imshow(pred, cmap="jet", alpha=0.6)

# %%
import torch
import random
import numpy as np
import matplotlib.pyplot as plt

# Select a random sample from test_ds
random_index = random.randint(0, len(test_ds) - 1)
sample = test_ds[random_index]

# Extract image and label
image_tensor = sample["image"].unsqueeze(0).to(device)  # [1, C, H, W, D]
label = sample["label"].cpu().numpy()                   # [C, H, W, D]

# Choose central slice in z-direction
z_index = image_tensor.shape[-1] // 2

# Run inference
model.eval()
with torch.no_grad():
    prediction = model(image_tensor)
    prediction = post_pred(prediction[0].cpu())  # Apply argmax+onehot
    prediction = prediction.numpy()

# Extract relevant slices
image_slice = image_tensor.cpu().numpy()[0, 0, :, :, z_index]
label_slice = label[0, :, :, z_index]
pred_slice = prediction[1, :, :, z_index]  # Class 1 (foreground) only

# Plot with overlays
plt.figure(figsize=(18, 6))

# Original image
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(image_slice, cmap="gray")
plt.axis("off")

# Image + Ground Truth Overlay
plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(image_slice, cmap="gray")
plt.imshow(label_slice, cmap="Blues", alpha=0.4)  # GT mask in blue
plt.axis("off")

# Image + Model Prediction Overlay
plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(image_slice, cmap="gray")
plt.imshow(pred_slice, cmap="Reds", alpha=0.4)    # Prediction mask in red
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Select a random sample from test_loader
random_index = random.randint(0, len(test_ds) - 1)  # Get a random index

# Load the sample
sample = test_ds[random_index]

# Extract image, ground truth, and model prediction
image = sample["image"].unsqueeze(0).to(device)  # Add batch dimension
label = sample["label"].cpu().numpy()[0, :, :, 64]  # Extract slice in z-direction

# Get model prediction
with torch.no_grad():
    pred = model(image)
    pred = post_pred(pred[0].cpu()).numpy()[0, :, :, 64]  # Extract slice

# Convert image for visualization
image = image.cpu().numpy()[0, 0, :, :, 64]  # Extract grayscale image slice

# Binarize the Ground Truth and Prediction
label = (label > 0.5).astype(np.uint8)  # Convert to 0 and 1
pred = (pred > 0.5).astype(np.uint8)    # Convert to 0 and 1

# Fix Reversed Labels
# If segmentation appears inverted, flip values (0 ↔ 1)
if np.mean(pred) > 0.5:  # If prediction is mostly 1s (inverted), flip it
    pred = 1 - pred

# Plot the image, ground truth, and prediction
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(image, cmap="gray")

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(image, cmap="gray")  # Show grayscale image
plt.imshow(label, cmap="jet", alpha=0.5)  # Overlay label

plt.subplot(1, 3, 3)
plt.title("Model Prediction")
plt.imshow(image, cmap="gray")  # Show grayscale image
plt.imshow(pred, cmap="jet", alpha=0.5)  # Overlay prediction

plt.show()
